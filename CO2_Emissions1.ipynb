# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('co2_emissions (1) (2) (1).csv')
df.head(10)
# Out:
#     make       model vehicle_class  engine_size  cylinders transmission  \
# 0  ACURA         ILX       COMPACT          2.0          4           AS
# 1  ACURA         ILX       COMPACT          2.4          4            M
# 2  ACURA  ILX HYBRID       COMPACT          1.5          4           AV
# 3  ACURA     MDX 4WD   SUV - SMALL          3.5          6           AS
# 4  ACURA     RDX AWD   SUV - SMALL          3.5          6           AS
# 5  ACURA         RLX      MID-SIZE          3.5          6           AS
# 6  ACURA          TL      MID-SIZE          3.5          6           AS
# 7  ACURA      TL AWD      MID-SIZE          3.7          6           AS
# 8  ACURA      TL AWD      MID-SIZE          3.7          6            M
# 9  ACURA         TSX       COMPACT          2.4          4           AS
#
#   fuel_type  fuel_consumption_city  fuel_consumption_hwy  \
# 0         Z                    9.9                   6.7
# 1         Z                   11.2                   7.7
# 2         Z                    6.0                   5.8
# 3         Z                   12.7                   9.1
# 4         Z                   12.1                   8.7
# 5         Z                   11.9                   7.7
# 6         Z                   11.8                   8.1
# 7         Z                   12.8                   9.0
# 8         Z                   13.4                   9.5
# 9         Z                   10.6                   7.5
#
#    fuel_consumption_comb(l/100km)  fuel_consumption_comb(mpg)  co2_emissions
# 0                             8.5                          33            196
# 1                             9.6                          29            221
# 2                             5.9                          48            136
# 3                            11.1                          25            255
# 4                            10.6                          27            244
# 5                            10.0                          28            230
# 6                            10.1                          28            232
# 7                            11.1                          25            255
# 8                            11.6                          24            267
# 9                             9.2                          31            212

# %%
df.describe()
# Out:
#        engine_size    cylinders  fuel_consumption_city  fuel_consumption_hwy  \
# count  7385.000000  7385.000000            7385.000000           7385.000000
# mean      3.160068     5.615030              12.556534              9.041706
# std       1.354170     1.828307               3.500274              2.224456
# min       0.900000     3.000000               4.200000              4.000000
# 25%       2.000000     4.000000              10.100000              7.500000
# 50%       3.000000     6.000000              12.100000              8.700000
# 75%       3.700000     6.000000              14.600000             10.200000
# max       8.400000    16.000000              30.600000             20.600000
#
#        fuel_consumption_comb(l/100km)  fuel_consumption_comb(mpg)  \
# count                     7385.000000                 7385.000000
# mean                        10.975071                   27.481652
# std                          2.892506                    7.231879
# min                          4.100000                   11.000000
# 25%                          8.900000                   22.000000
# 50%                         10.600000                   27.000000
# 75%                         12.600000                   32.000000
# max                         26.100000                   69.000000
#
#        co2_emissions
# count    7385.000000
# mean      250.584699
# std        58.512679
# min        96.000000
# 25%       208.000000
# 50%       246.000000
# 75%       288.000000
# max       522.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7385 entries, 0 to 7384
# Data columns (total 12 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   make                            7385 non-null   object
#  1   model                           7385 non-null   object
#  2   vehicle_class                   7385 non-null   object
#  3   engine_size                     7385 non-null   float64
#  4   cylinders                       7385 non-null   int64
#  5   transmission                    7385 non-null   object
#  6   fuel_type                       7385 non-null   object
#  7   fuel_consumption_city           7385 non-null   float64
#  8   fuel_consumption_hwy            7385 non-null   float64
#  9   fuel_consumption_comb(l/100km)  7385 non-null   float64
#  10  fuel_consumption_comb(mpg)      7385 non-null   int64
#  11  co2_emissions                   7385 non-null   int64
# dtypes: float64(4), int64(3), object(5)
# memory usage: 692.5+ KB

# %%
df['cylinders'].value_counts()
# Out:
# 4     3220
# 6     2446
# 8     1402
# 12     151
# 3       95
# 10      42
# 5       26
# 16       3
# Name: cylinders, dtype: int64

# %%
df.duplicated().sum()
# Out:
# 1112

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Changing label into meaningful label

# %%
df["transmission"] = np.where(df["transmission"]=='A', "Automatic", df["transmission"])
df["transmission"] = np.where(df["transmission"]=='AM', "Automated Manual", df["transmission"])
df["transmission"] = np.where(df["transmission"]=='AS', "Automatic with Select Shift", df["transmission"])
df["transmission"] = np.where(df["transmission"]=='AV', "Continuously Variable", df["transmission"])
df["transmission"] = np.where(df["transmission"]=='M', "Manual", df["transmission"])

# %%
df["fuel_type"] = np.where(df["fuel_type"]=="Z", "Premium Gasoline", df["fuel_type"])
df["fuel_type"] = np.where(df["fuel_type"]=="X", "Regular Gasoline", df["fuel_type"])
df["fuel_type"] = np.where(df["fuel_type"]=="D", "Diesel", df["fuel_type"])
df["fuel_type"] = np.where(df["fuel_type"]=="E", "Ethanol(E85)", df["fuel_type"])
df["fuel_type"] = np.where(df["fuel_type"]=="N", "Natural Gas", df["fuel_type"])

# %%
df.head()
# Out:
#     make       model vehicle_class  engine_size  cylinders  \
# 0  ACURA         ILX       COMPACT          2.0          4
# 1  ACURA         ILX       COMPACT          2.4          4
# 2  ACURA  ILX HYBRID       COMPACT          1.5          4
# 3  ACURA     MDX 4WD   SUV - SMALL          3.5          6
# 4  ACURA     RDX AWD   SUV - SMALL          3.5          6
#
#                   transmission         fuel_type  fuel_consumption_city  \
# 0  Automatic with Select Shift  Premium Gasoline                    9.9
# 1                       Manual  Premium Gasoline                   11.2
# 2        Continuously Variable  Premium Gasoline                    6.0
# 3  Automatic with Select Shift  Premium Gasoline                   12.7
# 4  Automatic with Select Shift  Premium Gasoline                   12.1
#
#    fuel_consumption_hwy  fuel_consumption_comb(l/100km)  \
# 0                   6.7                             8.5
# 1                   7.7                             9.6
# 2                   5.8                             5.9
# 3                   9.1                            11.1
# 4                   8.7                            10.6
#
#    fuel_consumption_comb(mpg)  co2_emissions
# 0                          33            196
# 1                          29            221
# 2                          48            136
# 3                          25            255
# 4                          27            244

# %%
corr=df.corr()
sns.heatmap(corr,annot=True,cmap='tab20c')
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df)

# %%
for i in df.columns:
  if  df[i].dtype =='float64' or df[i].dtype =='int64':
    print("-------------------------------------")
    print("Distribution plot for",i)
    print("-------------------------------------")
    sns.displot(df[i],color='grey')
    plt.show()
# Out:
# -------------------------------------
# Distribution plot for engine_size
# -------------------------------------
# -------------------------------------
# Distribution plot for cylinders
# -------------------------------------
# -------------------------------------
# Distribution plot for fuel_consumption_city
# -------------------------------------
# -------------------------------------
# Distribution plot for fuel_consumption_hwy
# -------------------------------------
# -------------------------------------
# Distribution plot for fuel_consumption_comb(l/100km)
# -------------------------------------
# -------------------------------------
# Distribution plot for fuel_consumption_comb(mpg)
# -------------------------------------
# -------------------------------------
# Distribution plot for co2_emissions
# -------------------------------------

# %%
for i in df.columns:
  if  df[i].dtype =='float64' or df[i].dtype =='int64':
    print("-------------------------------------")
    print("Boxplot plot for",i)
    print("-------------------------------------")
    sns.boxplot(df[i])
    plt.show()
# Out:
# -------------------------------------
# Boxplot plot for engine_size
# -------------------------------------
# C:\Users\anike\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# -------------------------------------
# Boxplot plot for cylinders
# -------------------------------------
# C:\Users\anike\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\anike\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# -------------------------------------
# Boxplot plot for fuel_consumption_city
# -------------------------------------
# C:\Users\anike\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# -------------------------------------
# Boxplot plot for fuel_consumption_hwy
# -------------------------------------
# -------------------------------------
# Boxplot plot for fuel_consumption_comb(l/100km)
# -------------------------------------
# C:\Users\anike\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# -------------------------------------
# Boxplot plot for fuel_consumption_comb(mpg)
# -------------------------------------
# C:\Users\anike\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\anike\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# -------------------------------------
# Boxplot plot for co2_emissions
# -------------------------------------

# %%
for i in df.columns:
  if  df[i].dtype =='object':
    print("----------------------")
    print("Value counts for ",i)
    print("----------------------")

    print(df[i].value_counts())
# Out:
# ----------------------
# Value counts for  make
# ----------------------
# FORD             575
# CHEVROLET        515
# BMW              501
# MERCEDES-BENZ    365
# PORSCHE          296
# GMC              289
# TOYOTA           274
# AUDI             263
# NISSAN           213
# MINI             200
# JEEP             200
# KIA              192
# VOLKSWAGEN       187
# HYUNDAI          184
# DODGE            180
# HONDA            159
# CADILLAC         141
# LEXUS            129
# MAZDA            127
# SUBARU           119
# JAGUAR           118
# VOLVO            118
# BUICK             92
# INFINITI          87
# LINCOLN           81
# LAND ROVER        76
# MITSUBISHI        73
# RAM               72
# CHRYSLER          64
# FIAT              56
# MASERATI          52
# ACURA             51
# ROLLS-ROYCE       48
# ASTON MARTIN      39
# LAMBORGHINI       37
# BENTLEY           35
# SCION             21
# ALFA ROMEO        19
# GENESIS           14
# SMART              7
# SRT                2
# BUGATTI            2
# Name: make, dtype: int64
# ----------------------
# Value counts for  model
# ----------------------
# F-150 FFV             32
# F-150 FFV 4X4         31
# MUSTANG               26
# FOCUS FFV             24
# F-150 4X4             20
#                       ..
# LS 500                 1
# LS 500h                1
# NX 300 AWD F SPORT     1
# RX 350 L AWD           1
# XC40 T4 AWD            1
# Name: model, Length: 2053, dtype: int64
# ----------------------
# Value counts for  vehicle_class
# ----------------------
# SUV - SMALL                 1004
# MID-SIZE                     981
# COMPACT                      902
# SUV - STANDARD               613
# SUBCOMPACT                   532
# FULL-SIZE                    508
# PICKUP TRUCK - STANDARD      474
# TWO-SEATER                   381
# MINICOMPACT                  274
# STATION WAGON - SMALL        212
# PICKUP TRUCK - SMALL         133
# VAN - PASSENGER               66
# SPECIAL PURPOSE VEHICLE       65
# MINIVAN                       61
# STATION WAGON - MID-SIZE      45
# VAN - CARGO                   22
# Name: vehicle_class, dtype: int64
# ----------------------
# Value counts for  transmission
# ----------------------
# Automatic with Select Shift    2720
# Automatic                      1536
# Manual                         1019
# Automated Manual                540
# Continuously Variable           458
# Name: transmission, dtype: int64
# ----------------------
# Value counts for  fuel_type
# ----------------------
# Regular Gasoline    3030
# Premium Gasoline    2765
# Ethanol(E85)         330
# Diesel               147
# Natural Gas            1
# Name: fuel_type, dtype: int64

# %% [markdown]
# 1. Correlation plot
# 2. count plots for object type
# 3. swarm plot/violin plots
# 4. emission plots by object cols

# %% [markdown]
# # Removing the outliers

# %%
def remove_outliers(df, col, multiplier=1.0):
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - (multiplier * IQR)
    upper_bound = Q3 + (multiplier * IQR)
    df = df[(df[col] >= lower_bound) & (df[col] <= upper_bound)]
    return df

# %%
for i in df.columns:
    if df[i].dtype =='float64' or df[i].dtype =='int64':
        print("-------------------------------------")
        print("Distribution plot for",i)
        print("-------------------------------------")
        df=remove_outliers(df,i)
        sns.boxplot(df[i])
        plt.show()
# Out:
# C:\Users\anike\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# -------------------------------------
# Distribution plot for engine_size
# -------------------------------------
# -------------------------------------
# Distribution plot for cylinders
# -------------------------------------
# C:\Users\anike\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# -------------------------------------
# Distribution plot for fuel_consumption_city
# -------------------------------------
# C:\Users\anike\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# -------------------------------------
# Distribution plot for fuel_consumption_hwy
# -------------------------------------
# C:\Users\anike\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# -------------------------------------
# Distribution plot for fuel_consumption_comb(l/100km)
# -------------------------------------
# C:\Users\anike\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\anike\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# -------------------------------------
# Distribution plot for fuel_consumption_comb(mpg)
# -------------------------------------
# -------------------------------------
# Distribution plot for co2_emissions
# -------------------------------------
# C:\Users\anike\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4917 entries, 0 to 7384
# Data columns (total 12 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   make                            4917 non-null   object
#  1   model                           4917 non-null   object
#  2   vehicle_class                   4917 non-null   object
#  3   engine_size                     4917 non-null   float64
#  4   cylinders                       4917 non-null   int64
#  5   transmission                    4917 non-null   object
#  6   fuel_type                       4917 non-null   object
#  7   fuel_consumption_city           4917 non-null   float64
#  8   fuel_consumption_hwy            4917 non-null   float64
#  9   fuel_consumption_comb(l/100km)  4917 non-null   float64
#  10  fuel_consumption_comb(mpg)      4917 non-null   int64
#  11  co2_emissions                   4917 non-null   int64
# dtypes: float64(4), int64(3), object(5)
# memory usage: 499.4+ KB

# %%
for col in df.columns[2:-1]:
    sns.scatterplot(x=col, y='co2_emissions', data=df)
    plt.xlabel(col)
    plt.ylabel('co2.emissions')
    plt.title(f'Scatter plot of co2_emission vs {col}.')
    plt.tight_layout()
    plt.show()

# %%
from tabulate import tabulate
print("Make")
print(tabulate(pd.DataFrame(df.make.value_counts())))
plt.figure(figsize=(19,5));
df.groupby("make")["make"].count().sort_values(ascending=False).plot(kind="bar")
plt.title("Frequency distribution of feature : Make", fontsize=20)
plt.ylabel("Frequency", fontsize=15)
plt.xlabel("Brand Name", fontsize=15)
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
# Out:
# Make
# -------------  ---
# BMW            458
# FORD           422
# CHEVROLET      323
# PORSCHE        283
# MERCEDES-BENZ  261
# AUDI           237
# MINI           199
# JEEP           186
# NISSAN         182
# TOYOTA         174
# VOLKSWAGEN     171
# KIA            170
# GMC            169
# HYUNDAI        162
# HONDA          120
# CADILLAC       119
# SUBARU         119
# VOLVO          118
# MAZDA          117
# JAGUAR         113
# LEXUS          111
# BUICK           86
# DODGE           83
# INFINITI        74
# LINCOLN         68
# MITSUBISHI      59
# FIAT            53
# LAND ROVER      50
# ACURA           49
# CHRYSLER        49
# RAM             37
# MASERATI        34
# SCION           19
# ALFA ROMEO      19
# GENESIS         13
# BENTLEY          7
# ASTON MARTIN     3
# -------------  ---

# %%
print("model")
print(tabulate(pd.DataFrame(df.model.value_counts())))
plt.figure(figsize=(19,5));
df.groupby("model")["model"].count().sort_values(ascending=False)[:20].plot(kind="bar")
plt.title("Frequency distribution of feature :model", fontsize=20)
plt.ylabel("Frequency", fontsize=15)
plt.xlabel("Brand Name", fontsize=15)
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
# Out:
# model
# -----------------------------------------  --
# MUSTANG                                    25
# FOCUS FFV                                  24
# F-150 4X4                                  19
# F-150                                      18
# COMPASS                                    18
# SONIC 5                                    18
# JETTA                                      18
# ATS                                        18
# SONIC                                      17
# PATRIOT                                    16
# ACCORD                                     16
# FUSION                                     15
# CAMARO                                     15
# TACOMA 4WD                                 15
# FORTE 5                                    15
# PASSAT                                     15
# FORTE KOUP                                 15
# COLORADO                                   14
# BEETLE                                     14
# F-150 FFV                                  14
# F-150 FFV 4X4                              14
# CANYON                                     14
# EDGE AWD                                   13
# OUTBACK AWD                                13
# COROLLA                                    13
# FORTE                                      13
# ELANTRA                                    13
# LEGACY AWD                                 13
# LANCER                                     12
# 200 FFV                                    12
# SOUL                                       12
# FORESTER AWD                               12
# MUSTANG CONVERTIBLE                        12
# FRONTIER                                   12
# ELANTRA GT                                 12
# BRZ                                        11
# COLORADO 4WD                               11
# CHARGER FFV                                11
# CANYON 4WD                                 11
# COMPASS 4X4                                10
# ESCAPE                                     10
# COOPER CONVERTIBLE                         10
# SONATA                                     10
# F-150 (LT Tire Pkg)                        10
# ACCENT                                     10
# VERANO                                     10
# COOPER S CONVERTIBLE                       10
# BEETLE CONVERTIBLE                         10
# A5 QUATTRO                                 10
# Q50 AWD                                    10
# A4 QUATTRO                                 10
# SENTRA                                      9
# TERRAIN AWD                                 9
# TACOMA                                      9
# TERRAIN                                     9
# MKC AWD                                     9
# ATS AWD                                     9
# TUCSON                                      9
# FIESTA                                      9
# ESCAPE AWD                                  9
# RIO                                         9
# MALIBU                                      9
# CAMRY                                       9
# CTS                                         9
# CTS AWD                                     9
# CX-5                                        9
# A6 QUATTRO                                  9
# F-150 (Payload Pkg)                         9
# CT6 AWD                                     9
# A8L                                         9
# OPTIMA                                      9
# S5                                          9
# EQUINOX                                     9
# F-150 4X4 (LT Tire Pkg)                     9
# CRUZE                                       9
# FRONTIER 4WD                                9
# EQUINOX AWD                                 9
# OUTLANDER 4WD                               9
# RVR                                         9
# IMPREZA WAGON AWD                           8
# MX-5                                        8
# SILVERADO                                   8
# IMPREZA AWD                                 8
# Silverado                                   8
# COOPER S 5 DOOR                             8
# REGAL                                       8
# Sierra                                      8
# EDGE                                        8
# MICRA                                       8
# COOPER S 3 DOOR                             8
# Sierra 4WD                                  8
# 911 CARRERA 4 CABRIOLET                     8
# COOPER 5 DOOR                               8
# 911 CARRERA 4                               8
# COOPER S COUNTRYMAN ALL4                    8
# PATRIOT 4X4                                 8
# Q5                                          8
# CHEROKEE 4X4 ACTIVE DRIVE II                8
# A8                                          8
# JOHN COOPER WORKS COUNTRYMAN ALL4           8
# MKZ AWD                                     8
# GOLF                                        8
# JUKE                                        8
# VELOSTER TURBO                              8
# SPORTAGE                                    8
# 911 CARRERA                                 8
# TRAX                                        8
# 911 CARRERA 4S                              8
# M4 CABRIOLET                                8
# SIERRA                                      8
# M4 COUPE                                    8
# GOLF GTI                                    8
# 911 CARRERA S CABRIOLET                     8
# 911 CARRERA S                               8
# TIGUAN                                      8
# 911 CARRERA CABRIOLET                       8
# 911 CARRERA 4S CABRIOLET                    8
# SORENTO AWD                                 8
# SPORTAGE AWD                                8
# F-150 4X4 (Payload Pkg)                     7
# Silverado 4WD                               7
# CX-5 4WD                                    7
# MAZDA5                                      7
# FUSION AWD                                  7
# SORENTO                                     7
# CHARGER                                     7
# CHEROKEE                                    7
# JOHN COOPER WORKS CONVERTIBLE               7
# RVR 4WD                                     7
# ALTIMA                                      7
# Camaro                                      7
# VELOSTER                                    7
# SIERRA 4WD                                  7
# FOCUS                                       7
# 370Z ROADSTER                               7
# ILX                                         7
# IMPALA                                      7
# Elantra                                     7
# S4                                          7
# SILVERADO 4WD                               7
# 500L                                        7
# WRX AWD                                     6
# CAYMAN                                      6
# COOPER S CLUBMAN                            6
# RONDO                                       6
# Q7                                          6
# 340i                                        6
# EQUINOX AWD FFV                             6
# COOPER COUNTRYMAN                           6
# EQUINOX FFV                                 6
# Z4 sDRIVE28i                                6
# ACADIA AWD                                  6
# ACADIA                                      6
# COOPER CLUBMAN                              6
# WRX                                         6
# CAYMAN S                                    6
# BOXSTER                                     6
# BOXSTER S                                   6
# VENZA                                       6
# ES 350                                      6
# 340i xDRIVE                                 6
# CAYMAN GTS                                  6
# Mustang Convertible                         6
# K900                                        6
# BOXSTER GTS                                 6
# SQ5                                         6
# 370Z                                        6
# 435i COUPE                                  6
# 428i COUPE                                  6
# 435i xDRIVE COUPE                           6
# QX50 AWD                                    6
# LANCER SPORTBACK                            6
# GT-R                                        6
# Mustang                                     6
# V60 T6 AWD                                  6
# XC60 T5 AWD                                 6
# JOHN COOPER WORKS PACEMAN ALL4              6
# XC60 T6 AWD                                 6
# RENEGADE FFV                                6
# RENEGADE 4X4                                6
# S60 T6 AWD                                  6
# TUCSON AWD                                  6
# 320i                                        6
# SANTA FE SPORT AWD                          6
# TERRAIN FFV                                 6
# COOPER S PACEMAN ALL4                       6
# WRANGLER UNLIMITED 4X4                      6
# SL 550                                      6
# VENZA 4WD                                   6
# GS 350 AWD                                  6
# 911 CARRERA 4 GTS                           6
# CLA 250                                     6
# 500 CABRIO                                  6
# 500 ABARTH HATCHBACK                        6
# 500 ABARTH CABRIO                           6
# M3                                          6
# MKX AWD                                     6
# tC                                          6
# MKZ                                         6
# HIGHLANDER                                  6
# DART                                        6
# Canyon                                      6
# Colorado                                    6
# 300 FFV                                     6
# MAZDA3 5-DOOR                               6
# TRAVERSE                                    6
# XV CROSSTREK AWD                            6
# COOPER 3 DOOR                               6
# CX-3                                        6
# JOHN COOPER WORKS                           6
# 911 CARRERA 4 GTS CABRIOLET                 6
# 911 CARRERA GTS                             6
# 911 TARGA 4S                                6
# 911 TARGA 4                                 6
# REGAL AWD                                   6
# RAV4 AWD                                    6
# 911 CARRERA GTS CABRIOLET                   6
# EXPLORER AWD                                6
# CHEROKEE FFV                                6
# MKS AWD                                     6
# E 300 4MATIC                                6
# A7 QUATTRO                                  5
# CONTINENTAL AWD                             5
# X4 M40i                                     5
# MAZDA3 5-DOOR (SIL)                         5
# B 250                                       5
# A3                                          5
# ATS-V                                       5
# RANGE ROVER EVOQUE                          5
# HR-V AWD                                    5
# MAZDA3 4-DOOR                               5
# HR-V                                        5
# F-TYPE S COUPE                              5
# A4                                          5
# F-TYPE COUPE                                5
# CTS Vsport                                  5
# IS 350 AWD                                  5
# XC90 T6 AWD                                 5
# MUSTANG (Performance Pkg)                   5
# 200 AWD FFV                                 5
# CHEROKEE 4X4                                5
# Q60 AWD                                     5
# QUATTROPORTE SQ4                            5
# CHEROKEE TRAILHAWK 4X4                      5
# SIERRA FFV                                  5
# A5 CABRIOLET QUATTRO                        5
# 500X                                        5
# S6                                          5
# S7                                          5
# SILVERADO FFV                               5
# MDX SH-AWD                                  5
# F-TYPE S CONVERTIBLE                        5
# WRANGLER 4X4                                5
# Soul                                        5
# FIT                                         5
# CR-V AWD                                    5
# CR-V                                        5
# TIGUAN 4MOTION                              5
# X1 xDRIVE28i                                5
# F-TYPE CONVERTIBLE                          5
# X5 xDRIVE50i                                5
# X6 xDRIVE50i                                5
# ENCLAVE                                     5
# SIENNA                                      5
# FIESTA ST                                   5
# Elantra GT                                  5
# RAV4                                        5
# EXPLORER FFV AWD                            5
# Accord                                      5
# XTS                                         5
# FR-S                                        5
# XTS Vsport AWD                              5
# Canyon 4WD                                  5
# DART FFV                                    5
# Colorado 4WD                                5
# Acadia                                      5
# SONIC RS                                    5
# SONIC 5 RS                                  5
# PILOT AWD                                   5
# CC                                          5
# MAZDA6                                      5
# QX60 AWD                                    5
# V60 T5                                      5
# NV200 CARGO VAN                             5
# ROGUE AWD                                   5
# TLX                                         5
# 640i xDRIVE GRAN COUPE                      5
# 650i xDRIVE CABRIOLET                       5
# 650i xDRIVE GRAN COUPE                      5
# 650i xDRIVE COUPE                           5
# CHEROKEE 4X4 FFV                            4
# JOHN COOPER WORKS COUPE                     4
# MURANO AWD                                  4
# HIGHLANDER HYBRID AWD                       4
# HIGHLANDER AWD                              4
# CLS 550 4MATIC                              4
# PATHFINDER 4WD PLATINUM                     4
# JOHN COOPER WORKS ROADSTER                  4
# xB                                          4
# SILVERADO 4WD FFV                           4
# E 400 4MATIC                                4
# SIERRA 4WD FFV                              4
# MAXIMA                                      4
# CRUZE LIMITED                               4
# JUKE AWD                                    4
# RLX HYBRID                                  4
# X5 xDRIVE35d                                4
# ACCORD COUPE                                4
# ACCORD SEDAN                                4
# E 400 4MATIC WAGON                          4
# V60 T5 AWD                                  4
# GLA 250 4MATIC                              4
# AVALON                                      4
# 640i xDRIVE CABRIOLET                       4
# PATHFINDER                                  4
# COOPER S COUPE                              4
# CITY EXPRESS                                4
# A4 ALLROAD QUATTRO                          4
# GENESIS COUPE                               4
# TRANSIT CONNECT VAN                         4
# EDGE (Start/Stop)                           4
# COOPER S ROADSTER                           4
# TOUAREG                                     4
# S3                                          4
# COOPER ROADSTER                             4
# JETTA GLI                                   4
# COOPER PACEMAN                              4
# RC 350 AWD                                  4
# 428i GRAN COUPE                             4
# 911 GT3                                     4
# S60 T5 AWD                                  4
# MAZDA3 4-DOOR (SIL)                         4
# B 250 4MATIC                                4
# CAYENNE                                     4
# SLK 250                                     4
# Q3                                          4
# C 300 4MATIC                                4
# SIENNA AWD                                  4
# S 550 4MATIC SWB                            4
# S 550 4MATIC LWB                            4
# M2                                          4
# PATHFINDER 4WD                              4
# PANAMERA 4S                                 4
# RENEGADE                                    4
# XT5 AWD                                     4
# M235i CABRIOLET                             4
# EXPLORER                                    4
# M240i Coupe M Performance                   4
# M240i Coupe                                 4
# M240i Cabriolet                             4
# 440i xDrive Coupe                           4
# TAURUS                                      4
# TAURUS AWD                                  4
# TAURUS FFV                                  4
# TAURUS FFV AWD                              4
# Sportage AWD                                4
# 750i xDRIVE                                 4
# Continental AWD                             4
# YUKON                                       4
# YUKON XL                                    4
# YUKON XL 4WD                                4
# ODYSSEY                                     4
# PILOT                                       4
# F-150 FFV (LT Tire Pkg)                     4
# 500                                         4
# SANTA FE SPORT                              4
# ENCLAVE AWD                                 4
# Q50                                         4
# S90 T6 AWD                                  4
# GOLF SPORTWAGEN                             4
# Q70 AWD                                     4
# Q70 HYBRID                                  4
# QX60                                        4
# QX60 HYBRID AWD                             4
# EXPLORER FFV                                4
# MAZDA3 5-DOOR (i-ELOOP)                     4
# CROSSTREK AWD                               4
# 500 HATCHBACK TURBO                         4
# LACROSSE                                    4
# LACROSSE AWD                                4
# Santa Fe AWD                                4
# Z4 sDRIVE35i                                4
# X6 xDRIVE35i                                4
# Terrain AWD                                 4
# X5 xDRIVE35i                                4
# Sierra 4WD AT4                              4
# XTS AWD                                     4
# Acadia AWD                                  4
# SUBURBAN                                    4
# SUBURBAN 4WD                                4
# TAHOE                                       4
# G70 AWD                                     4
# X3 xDRIVE35i                                4
# TRAVERSE AWD                                4
# Explorer AWD                                4
# Escape AWD                                  4
# Edge AWD                                    4
# X3 xDRIVE28i                                4
# Equinox AWD                                 4
# M6 GRAN COUPE                               4
# DART GT                                     4
# DART TURBO AERO                             4
# Blazer                                      4
# M6 CABRIOLET                                4
# JOURNEY FFV                                 4
# QX70 AWD                                    4
# Sonata                                      4
# JOHN COOPER WORKS CLUBMAN ALL4              4
# AMG C 63                                    4
# S8                                          4
# M240i COUPE                                 4
# M240i CABRIOLET                             4
# 440i xDRIVE COUPE                           4
# 440i COUPE                                  4
# XC90 T5 AWD                                 4
# V60 CC T5 AWD                               4
# GOLF R                                      4
# S5 CABRIOLET                                4
# GS 450h                                     4
# RS 7                                        4
# AMG C 63 S                                  4
# Legacy AWD                                  4
# ALPINA B6 xDRIVE GRAN COUPE                 4
# MX-5 (SIL)                                  4
# LS 460 AWD                                  4
# LS 460 L AWD                                4
# Outback AWD                                 4
# Corolla                                     4
# RX 350 AWD                                  4
# RX 450h AWD                                 4
# MKT AWD                                     4
# Golf                                        4
# CX-9 4WD                                    4
# MAZDA3 4-DOOR (i-ELOOP)                     4
# RDX AWD                                     4
# CADENZA                                     4
# S60 T5                                      4
# CIVIC HATCHBACK                             4
# G90 AWD                                     4
# COOPER COUNTRYMAN ALL4                      4
# COOPER CLUBMAN ALL4                         4
# F-150 FFV 4X4 (LT Tire Pkg)                 4
# CRUZE HATCHBACK                             4
# Qashqai                                     4
# G80 AWD                                     4
# Outlander 4WD                               3
# John Cooper Works 3 Door                    3
# Frontier                                    3
# Cooper S Countryman ALL4                    3
# Mazda3 5-Door                               3
# Frontier 4WD                                3
# Tacoma 4WD                                  3
# Cooper S Clubman ALL4                       3
# F-TYPE Convertible                          3
# GENESIS AWD                                 3
# John Cooper Works Convertible               3
# John Cooper Works Clubman ALL4              3
# Cooper S 5 Door                             3
# Golf GTI                                    3
# Jetta GLI                                   3
# X4 xDRIVE28i                                3
# X3 xDRIVE28d                                3
# Wrangler 4X4                                3
# SONATA SPORT/LIMITED                        3
# Veloster Turbo                              3
# Wrangler Unlimited 4X4                      3
# RC F                                        3
# Impreza 4-Door AWD                          3
# Sentra                                      3
# Cooper Countryman ALL4                      3
# Cooper 3 Door                               3
# 911 Carrera S                               3
# SEDONA SXL                                  3
# Sorento AWD                                 3
# Wrangler JL Unlimited 4X4                   3
# Cooper 5 Door                               3
# Cooper Clubman ALL4                         3
# Wrangler JL 4X4                             3
# John Cooper Works Countryman ALL4           3
# Cooper Convertible                          3
# Cooper S 3 Door                             3
# Impreza 5-Door AWD                          3
# 911 Carrera S Cabriolet                     3
# Cherokee 4X4 Active Drive I                 3
# NX 200t AWD                                 3
# Cherokee                                    3
# F-TYPE Coupe                                3
# NX 200t AWD F SPORT                         3
# 911 Carrera 4S                              3
# 911 Carrera 4S Cabriolet                    3
# Crosstrek AWD                               3
# NX 300h AWD                                 3
# Cooper S Convertible                        3
# DISCOVERY SPORT                             3
# Tucson AWD                                  3
# AMG SLC 43                                  3
# ALTIMA SR                                   3
# RAV4 HYBRID AWD                             3
# BEETLE DUNE                                 3
# XT5                                         3
# ESCAPE FFV                                  3
# AMG GLE 43 4MATIC                           3
# GLC 300 4MATIC                              3
# GOLF SPORTWAGEN 4MOTION                     3
# GLS 450 4MATIC                              3
# SL 450                                      3
# XC60 T5                                     3
# SLC 300                                     3
# COOPER S CLUBMAN ALL4                       3
# 86                                          3
# METRIS PASSENGER                            3
# METRIS CARGO                                3
# ENVISION AWD                                3
# GLE 400 4MATIC                              3
# CT6                                         3
# IMPALA FFV                                  3
# 500X AWD                                    3
# CX-3 4WD                                    3
# FOCUS RS AWD                                3
# TRANSIT CONNECT VAN FFV                     3
# QUATTROPORTE S                              3
# TRANSIT CONNECT WAGON LWB FFV               3
# QUATTROPORTE GTS                            3
# GHIBLI S                                    3
# RC 300 AWD                                  3
# IS 300 AWD                                  3
# GRAND CHEROKEE 4X4                          3
# GOLF ALLTRACK                               3
# V90 T6 AWD                                  3
# CLA 250 4MATIC                              3
# Equinox                                     3
# MURANO                                      3
# Envision AWD                                3
# JUKE NISMO RS AWD                           3
# JUKE NISMO RS                               3
# Regal AWD                                   3
# Blazer AWD                                  3
# Impala                                      3
# V90 CC T6 AWD                               3
# Malibu                                      3
# Charger FFV                                 3
# S 550 4MATIC COUPE                          3
# Terrain                                     3
# Civic Coupe                                 3
# Civic Hatchback Sport                       3
# M4 Coupe Competition                        3
# M2 Competition                              3
# 1500 ECODIESEL                              3
# 1500 4X4 ECODIESEL                          3
# PROMASTER CITY                              3
# 440i Coupe                                  3
# A6 quattro                                  3
# RAV4 LE/XLE                                 3
# WRX STI AWD                                 3
# LS 500 AWD                                  3
# NEW WRANGLER UNLIMITED 4X4                  3
# NEW WRANGLER 4X4                            3
# F-150 4X4 XL/XLT                            3
# F-150 FFV (Payload Pkg)                     3
# GOLF SPORTWAGON                             3
# X3 M40i                                     3
# RS 3                                        3
# M4 Coupe                                    3
# YARIS HATCHBACK                             3
# SEDONA                                      3
# 911 TURBO S CABRIOLET                       3
# CAYENNE S                                   3
# GHIBLI                                      3
# MKT LIVERY AWD                              3
# MKT LIVERY                                  3
# LS 600h L                                   3
# TSX                                         3
# PANAMERA                                    3
# PANAMERA 4                                  3
# PANAMERA 4S EXECUTIVE                       3
# LS 460                                      3
# PANAMERA S                                  3
# PANAMERA TURBO                              3
# PANAMERA TURBO EXECUTIVE                    3
# 750Li xDRIVE                                3
# 1500 4X4 FFV                                3
# 1500 FFV                                    3
# TT COUPE QUATTRO                            3
# XV CROSSTREK HYBRID AWD                     3
# 4RUNNER 4WD                                 3
# JOURNEY AWD                                 3
# JOURNEY                                     3
# CHARGER AWD FFV                             3
# CHARGER AWD                                 3
# HIGHLANDER HYBRID AWD LE                    3
# IS 350                                      3
# CHALLENGER                                  3
# RS 5                                        3
# 300 AWD FFV                                 3
# CC 4MOTION                                  3
# Q50 HYBRID AWD                              3
# 911 TURBO S                                 3
# M5                                          3
# 911 TURBO CABRIOLET                         3
# YUKON 4WD                                   3
# TRANSIT CONNECT WAGON                       3
# E 550 4MATIC                                3
# E 550 CABRIOLET                             3
# E 550 COUPE                                 3
# GL 350 BLUETEC 4MATIC                       3
# 550i xDRIVE GRAN TURISMO                    3
# E 250 BLUETEC 4MATIC                        3
# CIVIC                                       3
# 535i xDRIVE GRAN TURISMO                    3
# COOPER COUPE                                3
# 428i xDRIVE COUPE                           3
# 335i xDRIVE GRAN TURISMO                    3
# 328i xDRIVE TOURING                         3
# 328i xDRIVE GRAN TURISMO                    3
# EQUUS                                       3
# 320i xDRIVE                                 3
# SANTA FE                                    3
# FUSION (Start/Stop)                         3
# MAZDA6 (i-ELOOP)                            3
# OUTLANDER                                   3
# FLEX AWD                                    3
# FLEX                                        3
# TTS COUPE QUATTRO                           3
# TT ROADSTER QUATTRO                         3
# ROGUE                                       3
# 500 HATCHBACK                               3
# VERSA                                       3
# 911 TURBO                                   3
# 300 AWD                                     3
# ACTIVEHYBRID 5                              3
# Q3 QUATTRO                                  3
# M6                                          3
# LACROSSE eASSIST                            3
# TRAX AWD                                    3
# 300                                         3
# ENCORE AWD                                  3
# ENCORE                                      3
# SRX                                         3
# XJR LWB                                     3
# A3 CABRIOLET QUATTRO                        3
# A3 QUATTRO                                  3
# Z4 sDRIVE35is                               3
# TLX SH-AWD                                  3
# XJR                                         3
# GS 350                                      3
# TAHOE 4WD                                   3
# GX 460                                      3
# CRUZE HATCHBACK PREMIER                     2
# 500 ABARTH                                  2
# 328i xDRIVE                                 2
# M240i xDRIVE COUPE                          2
# LC 500                                      2
# 328i                                        2
# RIDGELINE AWD                               2
# XKR CONVERTIBLE                             2
# Cayman S                                    2
# 370Z Roadster                               2
# LC 500h                                     2
# Altima SR/Platinum                          2
# Cayman GTS                                  2
# 1500 HFE eTorque                            2
# M240i xDRIVE CABRIOLET                      2
# LS 500h AWD                                 2
# CONTINENTAL GT                              2
# TTS ROADSTER QUATTRO                        2
# Cayman                                      2
# Micra                                       2
# Pathfinder 4WD                              2
# TT RS                                       2
# Pathfinder 4WD Platinum                     2
# SANTA FE SPORT 4WD                          2
# Cayenne S                                   2
# CIVIC HATCHBACK SPORT                       2
# XKR COUPE                                   2
# WRANGLER JK UNLIMITED 4X4                   2
# 535i xDRIVE                                 2
# WRANGLER JK 4X4                             2
# PACIFICA                                    2
# 124 SPIDER                                  2
# CHEROKEE 4X4 ACTIVE DRIVE I FFV             2
# RANGE ROVER VELAR                           2
# WRANGLER 4X4 (2-DOOR)                       2
# 550i xDRIVE                                 2
# WRANGLER UNLIMITED 4X4 (4-DOOR)             2
# PATRIOT 4X4 TRAIL RATED                     2
# F-TYPE COUPE R-DYNAMIC                      2
# F-TYPE CONVERTIBLE R-DYNAMIC                2
# 335i                                        2
# 535d xDRIVE                                 2
# RIO ECO                                     2
# COMPASS 4X4 TRAIL RATED                     2
# Cayenne                                     2
# 528i xDRIVE                                 2
# IS 300                                      2
# XKR-S COUPE                                 2
# XKR-S CONVERTIBLE                           2
# KONA AWD                                    2
# 335i xDRIVE                                 2
# COOPER S COUNTRYMAN  ALL4                   2
# NEW COMPASS 4X4                             2
# CHEROKEE 4X4 ACTIVE DRIVE I                 2
# C 300 4MATIC CABRIOLET                      2
# 911 Carrera GTS Cabriolet                   2
# C 300 4MATIC COUPE                          2
# AMG C 43 4MATIC                             2
# COROLLA iM                                  2
# RS 5 CABRIOLET                              2
# 911 Carrera T                               2
# 911 Carrera 4                               2
# IMPREZA 5-DOOR AWD                          2
# GLE 550 4MATIC                              2
# IMPREZA 4-DOOR AWD                          2
# 911 Targa 4S                                2
# 911 Carrera 4 Cabriolet                     2
# 911 Targa 4 GTS                             2
# 911 Carrera 4 GTS                           2
# 911 Carrera 4 GTS Cabriolet                 2
# XJL AWD PORTFOLIO                           2
# SENTRA NISMO                                2
# 911 Targa 4                                 2
# XFR-S                                       2
# XFR                                         2
# SENTRA (Turbo)                              2
# QASHQAI AWD                                 2
# QASHQAI                                     2
# Q60 COUPE                                   2
# AMG GT S COUPE                              2
# CHEROKEE 4X4 ACTIVE DRIVE LOCK              2
# AMG GT COUPE                                2
# Qashqai AWD                                 2
# NEW COMPASS                                 2
# Sentra (Turbo)                              2
# Sentra Nismo                                2
# TUCSON 4WD                                  2
# JOHN COOPER WORKS 3 DOOR                    2
# Boxster S                                   2
# Q50 HYBRID                                  2
# Boxster GTS                                 2
# Civic Type R                                2
# Versa                                       2
# RANGE ROVER EVOQUE CONVERTIBLE              2
# MKC AWD (Start/Stop)                        2
# 911 Carrera                                 2
# 911 Carrera Cabriolet                       2
# 911 Carrera GTS                             2
# AMG C 63 CABRIOLET                          2
# AMG C 63 COUPE                              2
# AMG C 63 S CABRIOLET                        2
# Q60 CONVERTIBLE                             2
# AMG C 63 S COUPE                            2
# AMG GLA 45 4MATIC                           2
# AMG GLE 43 4MATIC COUPE                     2
# NX 300 AWD                                  2
# A5 Sportback quattro                        2
# AMG CLA 45 4MATIC                           2
# Tahoe 4WD FFV                               2
# Escape                                      2
# 200 SEDAN                                   2
# Edge                                        2
# EcoSport AWD                                2
# EcoSport                                    2
# 124 Spider                                  2
# X1 xDRIVE35i                                2
# F-TYPE Convertible R-Dynamic                2
# Charger                                     2
# F-TYPE Coupe R-Dynamic                      2
# F-TYPE R AWD Convertible                    2
# F-TYPE R AWD Coupe                          2
# Trax                                        2
# Traverse AWD                                2
# Tahoe 4WD                                   2
# Veloster                                    2
# ALPINA B7 xDRIVE SWB                        2
# Cherokee 4X4 Active Drive II                2
# Cherokee 4X4 Active Drive Lock              2
# Compass                                     2
# Compass 4X4                                 2
# TOWN & COUNTRY FFV                          2
# AVENGER                                     2
# Renegade                                    2
# Renegade 4X4                                2
# ALPINA B7 xDRIVE LWB                        2
# ACTIVEHYBRID 7L                             2
# GRAND CARAVAN FFV                           2
# Forte                                       2
# Optima                                      2
# Escape FFV                                  2
# Expedition 4X4                              2
# AMG GLC 43 4MATIC                           2
# SRX AWD                                     2
# Civic Sedan                                 2
# Civic Hatchback                             2
# Civic Coupe Si                              2
# CTS SEDAN                                   2
# Odyssey                                     2
# CTS SEDAN AWD                               2
# Passport AWD                                2
# Yukon 4WD FFV                               2
# Yukon 4WD                                   2
# Pilot AWD                                   2
# Ridgeline AWD                               2
# CTS SPORT WAGON                             2
# Accent                                      2
# CTS SPORT WAGON AWD                         2
# CAMARO 2LS                                  2
# Expedition MAX 4X4                          2
# CRUZE ECO                                   2
# REGAL eASSIST                               2
# ORLANDO                                     2
# Kona                                        2
# Transit Connect Wagon LWB FFV               2
# Transit Connect Wagon LWB                   2
# Transit Connect Van FFV                     2
# Transit Connect Van                         2
# Kona AWD                                    2
# Mustang Bullitt                             2
# Mustang (Performance Pkg)                   2
# Fusion                                      2
# Fiesta                                      2
# 200 CONVERTIBLE                             2
# Regal                                       2
# Rio                                         2
# Sedona                                      2
# A3 Cabriolet quattro                        2
# 740Li xDRIVE                                2
# Nautilus                                    2
# TT Roadster quattro                         2
# TT Coupe quattro                            2
# S5 Sportback                                2
# S5 Cabriolet                                2
# Navigator 4X4                               2
# Q8                                          2
# Ghibli S                                    2
# A7 quattro                                  2
# A5 Cabriolet quattro                        2
# A5 quattro                                  2
# SORENTO 4WD                                 2
# A4 quattro                                  2
# A3 quattro                                  2
# ACTIVEHYBRID 3                              2
# Vantage V8                                  2
# Stelvio AWD Quadrifoglio                    2
# Levante S                                   2
# Quattroporte S                              2
# Giulia Quadrifoglio                         2
# Mazda3 4-Door                               2
# RDX AWD A-SPEC                              2
# S90 T5 AWD                                  2
# Mazda3 5-Door (SIL)                         2
# C-HR                                        2
# Mazda6                                      2
# 911 TARGA 4 GTS                             2
# S 560 4MATIC SWB                            2
# S 450 4MATIC SWB                            2
# 230i xDrive Cabriolet                       2
# 230i xDrive Coupe                           2
# 430i xDrive Coupe                           2
# 430i xDrive Gran Coupe                      2
# Encore AWD                                  2
# Sportage                                    2
# Enclave AWD                                 2
# Stinger AWD                                 2
# X7 xDrive50i                                2
# X5 xDrive50i                                2
# Range Rover 3.0                             2
# X4 xDrive30i                                2
# X3 xDrive30i                                2
# X2 xDrive28i                                2
# X1 xDrive28i                                2
# M850i xDrive Coupe                          2
# M850i xDrive Cabriolet                      2
# M5 Competition                              2
# M4 CS                                       2
# 500L TURBO                                  2
# M4 Cabriolet Competition                    2
# M4 Cabriolet                                2
# M240i xDrive Coupe M Performance            2
# M240i xDrive Coupe                          2
# M240i xDrive Cabriolet                      2
# FLEX AWD (EcoBoost)                         2
# FOCUS SFE FFV                               2
# Alpina B7 xDrive                            2
# Range Rover 5.0 Supercharged                2
# Range Rover Sport 3.0                       2
# 440i xDrive Gran Coupe                      2
# 440i xDrive Cabriolet                       2
# TRANSIT CONNECT                             2
# A4 allroad quattro                          2
# Boxster                                     2
# IMPALA DUAL FUEL                            2
# LANCER AWD                                  2
# SLK 350                                     2
# 228i                                        2
# CT5                                         2
# CT5 AWD                                     2
# S5 QUATTRO                                  2
# S4 QUATTRO                                  2
# Q5 QUATTRO                                  2
# A8 QUATTRO                                  2
# MDX SH-AWD ELITE                            2
# XC70 T5                                     2
# JOHN COOPER WORKS CLUBMAN                   2
# LANCER EVOLUTION                            2
# CAYENNE TURBO                               2
# Mustang Convertible (Performance Pkg)       2
# Transit Connect Van LWB                     2
# Venue                                       2
# S80 T5                                      2
# QUEST                                       2
# 4RUNNER 4WD (Part-Time 4WD)                 2
# CAYENNE DIESEL (modified)                   2
# 1500 ECODIESEL HFE                          2
# PANAMERA TURBO S EXECUTIVE                  2
# PANAMERA TURBO S                            2
# MACAN TURBO                                 2
# ML 550 4MATIC                               2
# M235i                                       2
# CT4 AWD                                     2
# CT4                                         2
# F-TYPE S CONVERTIBLE AWD                    2
# F-TYPE R AWD COUPE                          2
# F-TYPE R AWD CONVERTIBLE                    2
# Q50S RED SPORT AWD                          2
# C 250 COUPE                                 2
# C 300 4MATIC FFV                            2
# CIVIC SEDAN                                 2
# CIVIC COUPE                                 2
# YUKON XL 4WD FFV                            2
# YUKON XL FFV                                2
# YUKON FFV                                   2
# SIERRA eASSIST 4WD                          2
# FOCUS ST                                    2
# FLEX AWD GTDI                               2
# DURANGO AWD                                 2
# TRAX 4WD                                    2
# TAHOE FFV                                   2
# SUBURBAN 4WD FFV                            2
# SUBURBAN FFV                                2
# SILVERADO eASSIST 4WD                       2
# 540i xDRIVE                                 2
# GLK 250 BLUETEC 4MATIC                      2
# GLK 350 4MATIC                              2
# MACAN S                                     2
# PANAMERA GTS                                2
# XJ R-SPORT 3.0 AWD                          2
# 335i SEDAN                                  2
# SANTA FE AWD                                2
# Corsair AWD                                 2
# 228i COUPE                                  2
# ELANTRA COUPE                               2
# 228i xDRIVE CABRIOLET                       2
# Nautilus AWD                                2
# 320i SEDAN                                  2
# CX-30                                       2
# 328i SEDAN                                  2
# CX-30 4WD                                   2
# EXPEDITION 4X4                              2
# 335i xDRIVE SEDAN                           2
# 1500 HFE                                    2
# 428i CABRIOLET                              2
# 200                                         2
# 428i xDRIVE CABRIOLET                       2
# 428i xDRIVE GRAN COUPE                      2
# 435i CABRIOLET                              2
# 435i xDRIVE CABRIOLET                       2
# 435i xDRIVE GRAN COUPE                      2
# X4 xDRIVE35i                                2
# M6 COUPE                                    2
# M3 SEDAN                                    2
# M235i COUPE                                 2
# SANTA FE ULTIMATE AWD                       2
# Q60                                         2
# XC70 AWD                                    2
# XC60 AWD                                    2
# 370Z COUPE                                  2
# xD                                          2
# Gladiator 4X4                               2
# COROLLA MATRIX                              2
# E 400 COUPE                                 2
# E 400 CABRIOLET                             2
# CLS 400 4MATIC                              2
# RLX                                         2
# RAV4 LIMITED AWD                            2
# Wrangler Unlimited 4X4 eTorque              2
# YARIS                                       2
# BEETLE TDI (modified)                       2
# NAVIGATOR 4X4                               2
# EOS                                         2
# GOLF WAGON                                  2
# RC 350                                      2
# GOLF WAGON TDI (modified)                   2
# JETTA TDI (modified)                        2
# RANGE ROVER SPORT                           2
# RANGE ROVER                                 2
# TOUAREG TDI (modified)                      2
# SEDONA SX                                   2
# S60 AWD                                     2
# F-TYPE S COUPE AWD                          2
# Civic Sedan Si                              2
# CAYENNE GTS                                 2
# 330i xDRIVE TOURING                         2
# 430i xDRIVE COUPE                           2
# S60 POLESTAR                                2
# A6 QUATTRO TDI (modified)                   2
# Golf R                                      2
# CX-9                                        2
# A7 QUATTRO TDI (modified)                   2
# GHIBLI AWD                                  2
# 340i xDRIVE GRAN TURISMO                    2
# GHIBLI SQ4                                  2
# V60 POLESTAR                                2
# LANCER 4WD                                  2
# MAZDA6 (SIL)                                2
# Yaris Hatchback                             2
# 4C                                          2
# IS 350 C                                    2
# Highlander                                  2
# Arteon 4MOTION                              2
# 330i xDRIVE GRAN TURISMO                    2
# 330i xDRIVE                                 2
# AMG CLA 45                                  2
# 230i xDRIVE COUPE                           2
# Camry XLE/XSE                               2
# 230i xDRIVE CABRIOLET                       2
# IS 250 C                                    2
# Camry LE/SE                                 2
# E 400 4MATIC COUPE                          2
# CLA 250 4MATIC FFV                          2
# RANGE ROVER EVOQUE COUPE                    2
# 230i COUPE                                  2
# Q5 HYBRID                                   2
# 430i xDRIVE GRAN COUPE                      2
# 430i xDRIVE CABRIOLET                       2
# Passat                                      2
# Highlander AWD                              2
# Tiguan 4MOTION                              2
# Tiguan                                      2
# 440i xDRIVE GRAN COUPE                      2
# S60 CC T5 AWD                               2
# iM                                          2
# S60 INSCRIPTION T5 AWD                      2
# TL AWD                                      2
# ...
# RANGE ROVER SPORT TD6 DIESEL                1
# GS 200t                                     1
# GS 200t F SPORT                             1
# GS 350 F SPORT                              1
# GS F                                        1
# RC 200t                                     1
# CX-5 (SIL)                                  1
# IS F                                        1
# RANGE ROVER SPORT V6 3.0 SC                 1
# MDX HYBRID AWD                              1
# NSX                                         1
# OPTIMA TURBO                                1
# F-TYPE R CONVERTIBLE AWD                    1
# F-TYPE R COUPE AWD                          1
# XE 35t AWD                                  1
# XF 35t AWD                                  1
# XJL PORTFOLIO 3.0 AWD                       1
# XJR  LWB                                    1
# FORTE (MPI)                                 1
# FORTE (GDI)                                 1
# OPTIMA FE                                   1
# SORENTO AWD FE                              1
# QX30 AWD                                    1
# SOUL TURBO                                  1
# XK COUPE                                    1
# XK CONVERTIBLE                              1
# XJL SUPERCHARGED                            1
# S 550 4MATIC CABRIOLET                      1
# XJ SUPERCHARGED                             1
# XJ AWD                                      1
# XF 3.0L AWD                                 1
# CAYENNE PLATINUM                            1
# F-PACE 35t                                  1
# QX30                                        1
# 4C SPIDER                                   1
# ENCORE (LE2 Engine)                         1
# GIULIA                                      1
# GIULIA AWD                                  1
# GIULIA QUADRIFOGLIO                         1
# A4 ULTRA                                    1
# FLYING SPUR                                 1
# 230i CABRIOLET                              1
# LR2                                         1
# ALPINA B7 xDRIVE                            1
# ENCORE (LUV Engine)                         1
# ENCORE AWD (LUV Engine)                     1
# Q60S RED SPORT AWD                          1
# ENCORE AWD (LE2 Engine)                     1
# COLORADO ZR2 4WD                            1
# CRUZE PREMIER                               1
# SPARK                                       1
# PACIFICA (Stop-Start)                       1
# CHALLENGER GT                               1
# GRAND CHEROKEE 4X4 FFV                      1
# GRAND CHEROKEE 4X4 DIESEL                   1
# FOCUS (Start/Stop)                          1
# YUKON 4WD FFV                               1
# C 350 4MATIC COUPE                          1
# C 350 COUPE                                 1
# C 400 4MATIC                                1
# F-TYPE V8 R COUPE                           1
# XF AWD                                      1
# XC90 AWD                                    1
# XC60                                        1
# S80 AWD                                     1
# S80                                         1
# S60                                         1
# ROUTAN                                      1
# TUNDRA                                      1
# CLA 45 AMG                                  1
# R8 SPYDER                                   1
# FJ CRUISER 4WD                              1
# GLA 45 AMG 4MATIC                           1
# ML 400 4MATIC                               1
# S 400 4MATIC                                1
# 4RUNNER (Part-Time 4WD)                     1
# TRIBECA AWD                                 1
# CARGO VAN FFV                               1
# 1500 DIESEL                                 1
# 1500 4X4 DIESEL                             1
# R8                                          1
# CONTINENTAL GT3-R                           1
# CAYENNE S HYBRID                            1
# 435i GRAN COUPE                             1
# M235i xDRIVE COUPE                          1
# 740Li xDRIVE SEDAN                          1
# 740Ld xDRIVE SEDAN                          1
# M5 SEDAN                                    1
# 550i xDRIVE SEDAN                           1
# 535i xDRIVE SEDAN                           1
# 535d xDRIVE SEDAN                           1
# 528i xDRIVE SEDAN                           1
# 528i SEDAN                                  1
# 200 AWD                                     1
# 228i CABRIOLET                              1
# 328i xDRIVE SEDAN                           1
# EDGE SPORT AWD                              1
# EXPLORER AWD (EcoBoost)                     1
# FIESTA SFE                                  1
# TRANSIT CONNECT WAGON TAXI                  1
# 320i xDRIVE SEDAN                           1
# 228i xDRIVE COUPE                           1
# CIVIC Si                                    1
# PILOT 4WD                                   1
# 1500                                        1
# 1500 4X4                                    1
# CL 550 4MATIC                               1
# MALIBU LIMITED                              1
# M235i xDRIVE                                1
# M235i xDRIVE CABRIOLET                      1
# ML 350 BLUETEC 4MATIC                       1
# ML 350 4MATIC FFV                           1
# ENCORE SPORT TOURING                        1
# ENCORE SPORT TOURING AWD                    1
# LACROSSE FFV                                1
# LACROSSE AWD FFV                            1
# CRUZE LIMITED ECO                           1
# E 400 HYBRID                                1
# SQ5 QUATTRO                                 1
# E 350 COUPE                                 1
# TAHOE 4WD FFV                               1
# E 350 CABRIOLET                             1
# E 350 4MATIC WAGON                          1
# E 350 4MATIC COUPE                          1
# E 350 4MATIC                                1
# CLA 45 AMG 4MATIC                           1
# TRANSIT CONNECT WAGON FFV                   1
# TRANSIT CONNECT WAGON LWB                   1
# 228i xDRIVE                                 1
# S8 QUATTRO                                  1
# S60 POLESTAR AWD                            1
# XC60 T6                                     1
# S60 T5                                      1
# S60 T6                                      1
# S80 T6 AWD                                  1
# V60 CC                                      1
# V60 CC AWD                                  1
# V60 POLESTAR AWD                            1
# PATHFINDER HYBRID 4WD                       1
# LANCER RALLIART                             1
# XC60 3.2 AWD                                1
# XC70 3.2 AWD                                1
# S7 QUATTRO                                  1
# XC70 T6 AWD                                 1
# A8 QUATTRO TDI (modified)                   1
# A8L QUATTRO                                 1
# Q5 QUATTRO TDI (modified)                   1
# Q5 HYBRID QUATTRO                           1
# RS 7 QUATTRO                                1
# S3 QUATTRO                                  1
# S5 CABRIOLET QUATTRO                        1
# S6 QUATTRO                                  1
# MACAN                                       1
# XF                                          1
# Accord Sport/Touring                        1
# F-TYPE V8 S CONVERTIBLE                     1
# 640i xDrive Gran Turismo                    1
# 650i xDrive Gran Coupe                      1
# 750i xDrive                                 1
# 750Li xDrive                                1
# Alpina B6 xDrive Gran Coupe                 1
# M550i xDrive                                1
# X5 xDrive40i                                1
# X6 xDrive35i                                1
# X6 xDrive50i                                1
# X7 xDrive40i                                1
# Enclave                                     1
# Encore                                      1
# Encore (SIDI with Stop/Start)               1
# Encore AWD (SIDI with Stop/Start)           1
# 500 CABRIO TURBO                            1
# LaCrosse                                    1
# LaCrosse eAssist                            1
# LaCrosse AWD                                1
# XT4                                         1
# XT4 AWD                                     1
# DURANGO AWD FFV                             1
# 640i xDrive Gran Coupe                      1
# 540i xDrive                                 1
# 530i xDrive                                 1
# 750i xDRIVE SEDAN                           1
# MDX SH-AWD A-SPEC                           1
# MDX Hybrid AWD                              1
# RLX Hybrid                                  1
# 4C Coupe                                    1
# 4C Spider                                   1
# Giulia                                      1
# Giulia AWD                                  1
# Stelvio                                     1
# Stelvio AWD                                 1
# TRANSIT CONNECT TAXI                        1
# 430i xDrive Cabriolet                       1
# Q3 quattro                                  1
# RS 5 Coupe                                  1
# RS 5 Sportback                              1
# TT RS Coupe                                 1
# TTS Coupe                                   1
# Bentayga                                    1
# 330i xDrive                                 1
# 330i xDrive Gran Turismo                    1
# 330i xDrive Touring                         1
# Colorado ZR2 4WD                            1
# Cruze                                       1
# Cruze Premier                               1
# Taurus AWD                                  1
# 200 CONVERTIBLE FFV                         1
# Explorer FFV AWD                            1
# F-150 4X4 Limited                           1
# Flex                                        1
# Flex AWD                                    1
# Flex AWD GTDI                               1
# Fiesta ST                                   1
# Ranger 4WD                                  1
# Taurus FFV                                  1
# Taurus FFV AWD                              1
# Journey FFV                                 1
# G70                                         1
# IMPALA ECO                                  1
# Sierra LTD                                  1
# Sierra LTD 4WD                              1
# CTS SEDAN Vsport                            1
# Yukon                                       1
# Yukon FFV                                   1
# Yukon XL                                    1
# Yukon XL FFV                                1
# Journey AWD                                 1
# Journey                                     1
# Cruze Hatchback                             1
# Tahoe FFV                                   1
# Cruze Hatchback Premier                     1
# AVENGER FFV                                 1
# Silverado 4WD Trail Boss                    1
# Silverado LD                                1
# Silverado LD 4WD                            1
# Spark                                       1
# Suburban                                    1
# Suburban FFV                                1
# Tahoe                                       1
# Traverse                                    1
# Grand Caravan FFV                           1
# Trax 4WD                                    1
# Pacifica                                    1
# Pacifica (Stop-Start)                       1
# Challenger                                  1
# Challenger GT AWD                           1
# 200 SEDAN FFV                               1
# Charger AWD                                 1
# Charger AWD FFV                             1
# Durango AWD                                 1
# V90 CC T5 AWD                               1
# BEETLE DUNE CONVERTIBLE                     1
# ATLAS 4MOTION                               1
# ACCORD SPORT/TOURING                        1
# ENCORE AWD (SIDI with Stop/Start)           1
# SILVERADO eASSIST                           1
# CHALLENGER GT AWD                           1
# CHALLENGER GT AWD FFV                       1
# ECOSPORT                                    1
# ECOSPORT AWD                                1
# EXPEDITION MAX 4X4                          1
# GENESIS                                     1
# SIERRA eASSIST                              1
# CIVIC COUPE Si                              1
# SANTA FE 4WD                                1
# CIVIC SEDAN Si                              1
# CIVIC TYPE R                                1
# ODYSSEY TOURING                             1
# KONA                                        1
# SANTA FE SPORT ULTIMATE AWD                 1
# Q50 AWD RED SPORT                           1
# Q60 AWD RED SPORT                           1
# F-PACE 20d                                  1
# F-PACE 25t                                  1
# ENCORE (SIDI with Stop/Start)               1
# X3 xDRIVE30i                                1
# F-TYPE COUPE R-DYNAMIC AWD                  1
# TLX SH-AWD A-SPEC                           1
# Q70                                         1
# COROLLA LE ECO (2-mode)                     1
# HIGHLANDER AWD (Start/Stop System)          1
# HIGHLANDER AWD LE                           1
# Q60 AWD COUPE                               1
# S60 INSCRIPTION T5                          1
# S90 T5                                      1
# V90 T5                                      1
# TLX A-SPEC                                  1
# 4C COUPE                                    1
# X2 xDRIVE28i                                1
# STELVIO AWD                                 1
# STELVIO QUADRIFOGLIO                        1
# DB11 V8                                     1
# A5 SPORTBACK QUATTRO                        1
# S5 SPORTBACK                                1
# TTS COUPE                                   1
# 640i xDRIVE GRAN TURISMO                    1
# 750i xDRIVE SWB                             1
# M550i xDRIVE                                1
# F-TYPE CONVERTIBLE R-DYNAMIC AWD            1
# XE 25t AWD                                  1
# ATLAS                                       1
# 911 TURBO S EXCLUSIVE                       1
# C 300 4MATIC WAGON                          1
# E 400 4MATIC CABRIOLET                      1
# GLC 300 4MATIC COUPE                        1
# S 560 CABRIOLET                             1
# S 560 4MATIC                                1
# S 560 4MATIC COUPE                          1
# ECLIPSE CROSS                               1
# ECLIPSE CROSS 4WD                           1
# KICKS                                       1
# MACAN TURBO KIT                             1
# AMG S 63 4MATIC CABRIOLET                   1
# PANAMERA 4 EXECUTIVE                        1
# PANAMERA 4 ST                               1
# PANAMERA 4S ST                              1
# PANAMERA TURBO ST                           1
# BRZ tS                                      1
# WRX STI AWD TYPE RA                         1
# CAMRY LE/SE                                 1
# CAMRY XLE/XSE                               1
# CAMRY XSE                                   1
# AMG S 63 4MATIC COUPE                       1
# AMG S 63 4MATIC                             1
# XF 25t AWD                                  1
# CX-5 (Cylinder Deactivation)                1
# XJ R-SPORT AWD                              1
# XJL PORTFOLIO AWD                           1
# CROSSTOUR AWD                               1
# STINGER AWD                                 1
# LS 500                                      1
# LS 500h                                     1
# NX 300 AWD F SPORT                          1
# RX 350 L AWD                                1
# CX-5                                        1
# CX-5 4WD (Cylinder Deactivation)            1
# AMG GT C ROADSTER                           1
# MAZDA6 TURBO                                1
# AMG C 43 4MATIC CABRIOLET                   1
# AMG C 43 4MATIC COUPE                       1
# AMG E 43 4MATIC                             1
# AMG E 63 S 4MATIC                           1
# AMG E 63 S 4MATIC WAGON                     1
# AMG GLC 43 4MATIC COUPE                     1
# AMG GT ROADSTER                             1
# AMG GT C COUPE                              1
# XC40 T4 AWD                                 1
# -----------------------------------------  --

# %%
print("vehicle_class")
print(tabulate(pd.DataFrame(df.vehicle_class.value_counts())))
plt.figure(figsize=(19,5));
df.groupby("vehicle_class")["vehicle_class"].count().sort_values(ascending=False).plot(kind="bar")
plt.title("Frequency distribution of feature : Make", fontsize=20)
plt.ylabel("Frequency", fontsize=15)
plt.xlabel("Brand Name", fontsize=15)
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
# Out:
# vehicle_class
# ------------------------  ---
# SUV - SMALL               980
# MID-SIZE                  781
# COMPACT                   752
# SUBCOMPACT                467
# FULL-SIZE                 376
# SUV - STANDARD            345
# MINICOMPACT               258
# PICKUP TRUCK - STANDARD   256
# TWO-SEATER                239
# STATION WAGON - SMALL     187
# PICKUP TRUCK - SMALL      130
# SPECIAL PURPOSE VEHICLE    59
# MINIVAN                    53
# STATION WAGON - MID-SIZE   34
# ------------------------  ---

# %%
df.head()
# Out:
#     make    model vehicle_class  engine_size  cylinders  \
# 0  ACURA      ILX       COMPACT          2.0          4
# 1  ACURA      ILX       COMPACT          2.4          4
# 3  ACURA  MDX 4WD   SUV - SMALL          3.5          6
# 4  ACURA  RDX AWD   SUV - SMALL          3.5          6
# 5  ACURA      RLX      MID-SIZE          3.5          6
#
#                   transmission         fuel_type  fuel_consumption_city  \
# 0  Automatic with Select Shift  Premium Gasoline                    9.9
# 1                       Manual  Premium Gasoline                   11.2
# 3  Automatic with Select Shift  Premium Gasoline                   12.7
# 4  Automatic with Select Shift  Premium Gasoline                   12.1
# 5  Automatic with Select Shift  Premium Gasoline                   11.9
#
#    fuel_consumption_hwy  fuel_consumption_comb(l/100km)  \
# 0                   6.7                             8.5
# 1                   7.7                             9.6
# 3                   9.1                            11.1
# 4                   8.7                            10.6
# 5                   7.7                            10.0
#
#    fuel_consumption_comb(mpg)  co2_emissions
# 0                          33            196
# 1                          29            221
# 3                          25            255
# 4                          27            244
# 5                          28            230

# %%
pd.crosstab(df['transmission'], df['cylinders']).plot(kind="bar",figsize=(10, 8), title="transmission & Cylinders");
plt.plot()
# Out:
# []

# %%
pd.crosstab(df['fuel_type'], df['cylinders']).plot(kind="bar",figsize=(10, 8), title="transmission & Cylinders");
plt.plot()
# Out:
# []

# %%
plt.rcParams["figure.figsize"] = (15,10)
sns.scatterplot(x='co2_emissions',y='cylinders',data = df,hue='fuel_type')
plt.xlabel("CO2 Emissions", fontsize=10)
plt.ylabel("Cylinders", fontsize=10)
plt.show()

# %% [markdown]
# # Feature selection

# %%
df['Make_Type'] = df['make'].replace(['BUGATTI', 'PORSCHE', 'MASERATI', 'ASTON MARTIN', 'LAMBORGHINI', 'JAGUAR','SRT'], 'Sports')
df['Make_Type'] = df['Make_Type'].replace(['ALFA ROMEO', 'AUDI', 'BMW', 'BUICK', 'CADILLAC', 'CHRYSLER', 'DODGE', 'GMC','INFINITI', 'JEEP', 'LAND ROVER', 'LEXUS', 'MERCEDES-BENZ','MINI', 'SMART', 'VOLVO'],'Premium')
df['Make_Type'] = df['Make_Type'].replace(['ACURA', 'BENTLEY', 'LINCOLN', 'ROLLS-ROYCE',  'GENESIS'], 'Luxury')
df['Make_Type'] = df['Make_Type'].replace(['CHEVROLET', 'FIAT', 'FORD', 'KIA', 'HONDA', 'HYUNDAI', 'MAZDA', 'MITSUBISHI','NISSAN', 'RAM', 'SCION', 'SUBARU', 'TOYOTA','VOLKSWAGEN'],'General')

# %%
df['Vehicle_Class_Type'] = df['vehicle_class'].replace(['COMPACT', 'MINICOMPACT', 'SUBCOMPACT'], 'Hatchback')
df['Vehicle_Class_Type'] = df['Vehicle_Class_Type'].replace(['MID-SIZE', 'TWO-SEATER', 'FULL-SIZE', 'STATION WAGON - SMALL', 'STATION WAGON - MID-SIZE'],'Sedan')
df['Vehicle_Class_Type'] = df['Vehicle_Class_Type'].replace(['SUV - SMALL', 'SUV - STANDARD', 'MINIVAN'],  'SUV')
df['Vehicle_Class_Type'] = df['Vehicle_Class_Type'].replace(['VAN - CARGO', 'VAN - PASSENGER', 'PICKUP TRUCK - STANDARD', 'SPECIAL PURPOSE VEHICLE', 'PICKUP TRUCK - SMALL'], 'Truck')

# %%
df.head()
# Out:
#     make    model vehicle_class  engine_size  cylinders  \
# 0  ACURA      ILX       COMPACT          2.0          4
# 1  ACURA      ILX       COMPACT          2.4          4
# 3  ACURA  MDX 4WD   SUV - SMALL          3.5          6
# 4  ACURA  RDX AWD   SUV - SMALL          3.5          6
# 5  ACURA      RLX      MID-SIZE          3.5          6
#
#                   transmission         fuel_type  fuel_consumption_city  \
# 0  Automatic with Select Shift  Premium Gasoline                    9.9
# 1                       Manual  Premium Gasoline                   11.2
# 3  Automatic with Select Shift  Premium Gasoline                   12.7
# 4  Automatic with Select Shift  Premium Gasoline                   12.1
# 5  Automatic with Select Shift  Premium Gasoline                   11.9
#
#    fuel_consumption_hwy  fuel_consumption_comb(l/100km)  \
# 0                   6.7                             8.5
# 1                   7.7                             9.6
# 3                   9.1                            11.1
# 4                   8.7                            10.6
# 5                   7.7                            10.0
#
#    fuel_consumption_comb(mpg)  co2_emissions Make_Type Vehicle_Class_Type
# 0                          33            196    Luxury          Hatchback
# 1                          29            221    Luxury          Hatchback
# 3                          25            255    Luxury                SUV
# 4                          27            244    Luxury                SUV
# 5                          28            230    Luxury              Sedan

# %%
df.drop(['make','model','vehicle_class'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    engine_size  cylinders                 transmission         fuel_type  \
# 0          2.0          4  Automatic with Select Shift  Premium Gasoline
# 1          2.4          4                       Manual  Premium Gasoline
# 3          3.5          6  Automatic with Select Shift  Premium Gasoline
# 4          3.5          6  Automatic with Select Shift  Premium Gasoline
# 5          3.5          6  Automatic with Select Shift  Premium Gasoline
#
#    fuel_consumption_city  fuel_consumption_hwy  \
# 0                    9.9                   6.7
# 1                   11.2                   7.7
# 3                   12.7                   9.1
# 4                   12.1                   8.7
# 5                   11.9                   7.7
#
#    fuel_consumption_comb(l/100km)  fuel_consumption_comb(mpg)  co2_emissions  \
# 0                             8.5                          33            196
# 1                             9.6                          29            221
# 3                            11.1                          25            255
# 4                            10.6                          27            244
# 5                            10.0                          28            230
#
#   Make_Type Vehicle_Class_Type
# 0    Luxury          Hatchback
# 1    Luxury          Hatchback
# 3    Luxury                SUV
# 4    Luxury                SUV
# 5    Luxury              Sedan

# %%
df['Make_Type'].unique()
# Out:
# array(['Luxury', 'Premium', 'General', 'Sports'], dtype=object)

# %%
df['Vehicle_Class_Type'].unique()
# Out:
# array(['Hatchback', 'SUV', 'Sedan', 'Truck'], dtype=object)

# %%
df['transmission'].unique()
# Out:
# array(['Automatic with Select Shift', 'Manual', 'Automated Manual',
#        'Continuously Variable', 'Automatic'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label_encoder =LabelEncoder()
df['transmission']= label_encoder.fit_transform(df['transmission']) 
df['fuel_type']= label_encoder.fit_transform(df['fuel_type']) 
df['Make_Type']= label_encoder.fit_transform(df['Make_Type']) 
df['Vehicle_Class_Type']= label_encoder.fit_transform(df['Vehicle_Class_Type'])

# %%
df.head()
# Out:
#    engine_size  cylinders  transmission  fuel_type  fuel_consumption_city  \
# 0          2.0          4             2          3                    9.9
# 1          2.4          4             4          3                   11.2
# 3          3.5          6             2          3                   12.7
# 4          3.5          6             2          3                   12.1
# 5          3.5          6             2          3                   11.9
#
#    fuel_consumption_hwy  fuel_consumption_comb(l/100km)  \
# 0                   6.7                             8.5
# 1                   7.7                             9.6
# 3                   9.1                            11.1
# 4                   8.7                            10.6
# 5                   7.7                            10.0
#
#    fuel_consumption_comb(mpg)  co2_emissions  Make_Type  Vehicle_Class_Type
# 0                          33            196          1                   0
# 1                          29            221          1                   0
# 3                          25            255          1                   1
# 4                          27            244          1                   1
# 5                          28            230          1                   2

# %%
df['Make_Type'].unique()#luxury=1,premium=2,General=0,Sports=3
# Out:
# array([1, 2, 0, 3])

# %%
df['Vehicle_Class_Type'].unique()#Hatchback=0, 'SUV'=1, 'Sedan'=2, 'Truck=3
# Out:
# array([0, 1, 2, 3])

# %%
df['transmission'].unique()#
# Out:
# array([2, 4, 0, 3, 1])

# %%
df.rename(columns={'fuel_consumption_comb(l/100km)':'fuel_consumption_comb_100km','fuel_consumption_comb(mpg)':'fuel_consumption_comb_mpg'},inplace=True)

# %%
df.corr()
# Out:
#                              engine_size  cylinders  transmission  fuel_type  \
# engine_size                     1.000000   0.932461     -0.243375  -0.032243
# cylinders                       0.932461   1.000000     -0.229618  -0.109592
# transmission                   -0.243375  -0.229618      1.000000   0.109026
# fuel_type                      -0.032243  -0.109592      0.109026   1.000000
# fuel_consumption_city           0.808130   0.779209     -0.245199  -0.098970
# fuel_consumption_hwy            0.729682   0.680966     -0.250006  -0.041616
# fuel_consumption_comb_100km     0.798710   0.762243     -0.252580  -0.080697
# fuel_consumption_comb_mpg      -0.768512  -0.727809      0.262829   0.091056
# co2_emissions                   0.808530   0.781240     -0.250276  -0.081445
# Make_Type                       0.226009   0.294006     -0.222056  -0.394315
# Vehicle_Class_Type              0.183186   0.121357     -0.104620   0.065159
#
#                              fuel_consumption_city  fuel_consumption_hwy  \
# engine_size                               0.808130              0.729682
# cylinders                                 0.779209              0.680966
# transmission                             -0.245199             -0.250006
# fuel_type                                -0.098970             -0.041616
# fuel_consumption_city                     1.000000              0.903795
# fuel_consumption_hwy                      0.903795              1.000000
# fuel_consumption_comb_100km               0.988310              0.957649
# fuel_consumption_comb_mpg                -0.971451             -0.941149
# co2_emissions                             0.945953              0.925937
# Make_Type                                 0.273334              0.187301
# Vehicle_Class_Type                        0.170076              0.214481
#
#                              fuel_consumption_comb_100km  \
# engine_size                                     0.798710
# cylinders                                       0.762243
# transmission                                   -0.252580
# fuel_type                                      -0.080697
# fuel_consumption_city                           0.988310
# fuel_consumption_hwy                            0.957649
# fuel_consumption_comb_100km                     1.000000
# fuel_consumption_comb_mpg                      -0.982717
# co2_emissions                                   0.960263
# Make_Type                                       0.248780
# Vehicle_Class_Type                              0.189531
#
#                              fuel_consumption_comb_mpg  co2_emissions  \
# engine_size                                  -0.768512       0.808530
# cylinders                                    -0.727809       0.781240
# transmission                                  0.262829      -0.250276
# fuel_type                                     0.091056      -0.081445
# fuel_consumption_city                        -0.971451       0.945953
# fuel_consumption_hwy                         -0.941149       0.925937
# fuel_consumption_comb_100km                  -0.982717       0.960263
# fuel_consumption_comb_mpg                     1.000000      -0.949581
# co2_emissions                                -0.949581       1.000000
# Make_Type                                    -0.278663       0.249445
# Vehicle_Class_Type                           -0.176290       0.212290
#
#                              Make_Type  Vehicle_Class_Type
# engine_size                   0.226009            0.183186
# cylinders                     0.294006            0.121357
# transmission                 -0.222056           -0.104620
# fuel_type                    -0.394315            0.065159
# fuel_consumption_city         0.273334            0.170076
# fuel_consumption_hwy          0.187301            0.214481
# fuel_consumption_comb_100km   0.248780            0.189531
# fuel_consumption_comb_mpg    -0.278663           -0.176290
# co2_emissions                 0.249445            0.212290
# Make_Type                     1.000000           -0.147821
# Vehicle_Class_Type           -0.147821            1.000000

# %%
order=['Make_Type','Vehicle_Class_Type','engine_size','cylinders','transmission','fuel_type','fuel_consumption_city', 'fuel_consumption_hwy','fuel_consumption_comb_100km' , 'fuel_consumption_comb_mpg','co2_emissions'] 
df=df[order]

# %%
df
# Out:
#       Make_Type  Vehicle_Class_Type  engine_size  cylinders  transmission  \
# 0             1                   0          2.0          4             2
# 1             1                   0          2.4          4             4
# 3             1                   1          3.5          6             2
# 4             1                   1          3.5          6             2
# 5             1                   2          3.5          6             2
# ...         ...                 ...          ...        ...           ...
# 7380          2                   1          2.0          4             2
# 7381          2                   1          2.0          4             2
# 7382          2                   1          2.0          4             2
# 7383          2                   1          2.0          4             2
# 7384          2                   1          2.0          4             2
#
#       fuel_type  fuel_consumption_city  fuel_consumption_hwy  \
# 0             3                    9.9                   6.7
# 1             3                   11.2                   7.7
# 3             3                   12.7                   9.1
# 4             3                   12.1                   8.7
# 5             3                   11.9                   7.7
# ...         ...                    ...                   ...
# 7380          3                   10.7                   7.7
# 7381          3                   11.2                   8.3
# 7382          3                   11.7                   8.6
# 7383          3                   11.2                   8.3
# 7384          3                   12.2                   8.7
#
#       fuel_consumption_comb_100km  fuel_consumption_comb_mpg  co2_emissions
# 0                             8.5                         33            196
# 1                             9.6                         29            221
# 3                            11.1                         25            255
# 4                            10.6                         27            244
# 5                            10.0                         28            230
# ...                           ...                        ...            ...
# 7380                          9.4                         30            219
# 7381                          9.9                         29            232
# 7382                         10.3                         27            240
# 7383                          9.9                         29            232
# 7384                         10.7                         26            248
#
# [4917 rows x 11 columns]

# %% [markdown]
# # train test split

# %%
x=df.drop('co2_emissions',axis=1)

# %%
x
# Out:
#       Make_Type  Vehicle_Class_Type  engine_size  cylinders  transmission  \
# 0             1                   0          2.0          4             2
# 1             1                   0          2.4          4             4
# 3             1                   1          3.5          6             2
# 4             1                   1          3.5          6             2
# 5             1                   2          3.5          6             2
# ...         ...                 ...          ...        ...           ...
# 7380          2                   1          2.0          4             2
# 7381          2                   1          2.0          4             2
# 7382          2                   1          2.0          4             2
# 7383          2                   1          2.0          4             2
# 7384          2                   1          2.0          4             2
#
#       fuel_type  fuel_consumption_city  fuel_consumption_hwy  \
# 0             3                    9.9                   6.7
# 1             3                   11.2                   7.7
# 3             3                   12.7                   9.1
# 4             3                   12.1                   8.7
# 5             3                   11.9                   7.7
# ...         ...                    ...                   ...
# 7380          3                   10.7                   7.7
# 7381          3                   11.2                   8.3
# 7382          3                   11.7                   8.6
# 7383          3                   11.2                   8.3
# 7384          3                   12.2                   8.7
#
#       fuel_consumption_comb_100km  fuel_consumption_comb_mpg
# 0                             8.5                         33
# 1                             9.6                         29
# 3                            11.1                         25
# 4                            10.6                         27
# 5                            10.0                         28
# ...                           ...                        ...
# 7380                          9.4                         30
# 7381                          9.9                         29
# 7382                         10.3                         27
# 7383                          9.9                         29
# 7384                         10.7                         26
#
# [4917 rows x 10 columns]

# %%
y=df['co2_emissions']

# %%
y
# Out:
# 0       196
# 1       221
# 3       255
# 4       244
# 5       230
#        ...
# 7380    219
# 7381    232
# 7382    240
# 7383    232
# 7384    248
# Name: co2_emissions, Length: 4917, dtype: int64

# %% [markdown]
# # RandomForest Regressor

# %%
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=1)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
regressor=RandomForestRegressor(n_estimators=100,random_state=42)

# %%
regressor.fit(x_train,y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
ypred=regressor.predict(x_test)

# %%
r2=metrics.r2_score(y_test,ypred)
r2
# Out:
# 0.9960409832881658

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
mse=metrics.mean_squared_error(y_test,ypred)
mse
# Out:
# 6.474142532167116

# %%
mae=metrics.mean_absolute_error(y_test,ypred)
mae
# Out:
# 1.7988514071971384

# %% [markdown]
# # DECISION TREE REGRESSOR

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dt=DecisionTreeRegressor(random_state=0)

# %%
dt.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
pred=dt.predict(x_test)

# %%
pred
# Out:
# array([277., 230., 205., ..., 239., 301., 197.])

# %%
r2_1=metrics.r2_score(y_test,pred)

# %%
r2_1
# Out:
# 0.9945884398256533

# %%
mse_dt=metrics.mean_squared_error(y_test,pred)
mse_dt
# Out:
# 8.849473099063474

# %%
mae_dt=metrics.mean_absolute_error(y_test,pred)
mae_dt
# Out:
# 1.8958720480061941

# %% [markdown]
# # SVM

# %%
from sklearn.svm import SVR

# %%
reg = SVR(kernel='linear')
reg.fit(x_train , y_train)
# Out:
# SVR(kernel='linear')

# %%
ypred_svm=reg.predict(x_test)

# %%
ypred_svm
# Out:
# array([275.12822981, 226.64091836, 204.16243213, ..., 237.93133902,
#        302.62400427, 196.82042275])

# %%
r2_svm=metrics.r2_score(y_test,ypred_svm)
r2_svm
# Out:
# 0.9121565100261888

# %% [markdown]
# # MLR

# %%
Lr=LinearRegression()

# %%
Lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred_lr=Lr.predict(x_test)

# %%
pred_lr
# Out:
# array([272.97522971, 225.04050077, 207.60888669, ..., 231.17376025,
#        300.82487227, 192.83086006])

# %%
r2_lr=metrics.r2_score(y_test,pred_lr)
r2_lr
# Out:
# 0.926105090527739

# %%
mse_lr=metrics.mean_squared_error(y_test,pred_lr)
mse_lr
# Out:
# 120.8396455854706

# %%
mae_lr=metrics.mean_absolute_error(y_test,pred_lr)
mae_lr
# Out:
# 5.295841936545181

# %%
# RF model is providing hghest score

# %% [markdown]
# # Feature scaling on Random forest model

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
train_sl=scaler.fit_transform(x_train)

# %%
test_sl=scaler.transform(x_test)

# %%
regressor_sl=RandomForestRegressor(n_estimators=100,random_state=42)

# %%
regressor_sl.fit(train_sl,y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
ypred=regressor_sl.predict(test_sl)

# %%
r2=metrics.r2_score(y_test,ypred)
r2
# Out:
# 0.9960818117493144

# %%
mse=metrics.mean_squared_error(y_test,ypred)
mse
# Out:
# 6.407376136345888

# %%
mae=metrics.mean_absolute_error(y_test,ypred)
mae
# Out:
# 1.795029184974917

# %%
# after feature scaling on Rf model we found out that normal Rf model is providing bettern score

# %% [markdown]
# # hyperparameter tuning on Random forest model

# %%
from sklearn.model_selection import train_test_split, RandomizedSearchCV

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
rf_model = RandomForestRegressor()

# %%
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'bootstrap': [True, False]
}

# %%
# Initialize RandomizedSearchCV
random_search = RandomizedSearchCV(estimator=rf_model, param_distributions=param_grid, n_iter=100, cv=5, random_state=42)

# %%
# Perform hyperparameter tuning
random_search.fit(x_train, y_train)
# Out:
# RandomizedSearchCV(cv=5, estimator=RandomForestRegressor(), n_iter=100,
#                    param_distributions={'bootstrap': [True, False],
#                                         'max_depth': [None, 10, 20, 30],
#                                         'min_samples_leaf': [1, 2, 4],
#                                         'min_samples_split': [2, 5, 10],
#                                         'n_estimators': [100, 200, 300]},
#                    random_state=42)

# %%
# Get the best parameters and best score
best_params = random_search.best_params_
best_score = random_search.best_score_

# %%
print("Best Parameters:", best_params)
print("Best Score:", best_score)
# Out:
# Best Parameters: {'n_estimators': 200, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_depth': 10, 'bootstrap': True}
# Best Score: 0.9920522866507557

# %%
# Make predictions on the test set using the best model
best_model = random_search.best_estimator_
y_pred = best_model.predict(x_test)

# %%
# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 6.015946435720777

# %%
R2=metrics.r2_score(y_test,y_pred)

# %%
print('R2 squared error:', R2)
# Out:
# R2 squared error: 0.996446537923835

# %% [markdown]
# # ANN

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from scikeras.wrappers import KerasClassifier
from sklearn.model_selection import cross_val_score

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %%
X_sl_train=scaler.fit_transform(X_train)

# %%
X_sl_test=scaler.transform(X_test)

# %%
import tensorflow as tf

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(1)  # Output layer
])
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
model.fit(X_sl_train, y_train, epochs=100, batch_size=32, verbose=1)
# Out:
# Epoch 1/100
# 123/123 [==============================] - 1s 1ms/step - loss: 52349.6289
# Epoch 2/100
# 123/123 [==============================] - 0s 1ms/step - loss: 19616.7305
# Epoch 3/100
# 123/123 [==============================] - 0s 1ms/step - loss: 6660.8047
# Epoch 4/100
# 123/123 [==============================] - 0s 1ms/step - loss: 3524.2502
# Epoch 5/100
# 123/123 [==============================] - 0s 1ms/step - loss: 1857.9260
# Epoch 6/100
# 123/123 [==============================] - 0s 1ms/step - loss: 1131.0867
# Epoch 7/100
# 123/123 [==============================] - 0s 1ms/step - loss: 769.1345
# Epoch 8/100
# 123/123 [==============================] - 0s 1ms/step - loss: 551.2496
# Epoch 9/100
# 123/123 [==============================] - 0s 1ms/step - loss: 414.9142
# Epoch 10/100
# 123/123 [==============================] - 0s 1ms/step - loss: 320.6144
# Epoch 11/100
# 123/123 [==============================] - 0s 1ms/step - loss: 256.9201
# Epoch 12/100
# 123/123 [==============================] - 0s 1ms/step - loss: 210.1398
# Epoch 13/100
# 123/123 [==============================] - 0s 1ms/step - loss: 174.0667
# Epoch 14/100
# 123/123 [==============================] - 0s 1ms/step - loss: 147.0698
# Epoch 15/100
# 123/123 [==============================] - 0s 1ms/step - loss: 126.9151
# Epoch 16/100
# 123/123 [==============================] - 0s 1ms/step - loss: 111.0319
# Epoch 17/100
# 123/123 [==============================] - 0s 1ms/step - loss: 99.3907
# Epoch 18/100
# 123/123 [==============================] - 0s 1ms/step - loss: 88.9404
# Epoch 19/100
# 123/123 [==============================] - 0s 1ms/step - loss: 80.7257
# Epoch 20/100
# 123/123 [==============================] - 0s 1ms/step - loss: 74.6762
# Epoch 21/100
# 123/123 [==============================] - 0s 1ms/step - loss: 68.3161
# Epoch 22/100
# 123/123 [==============================] - 0s 1ms/step - loss: 63.7479
# Epoch 23/100
# 123/123 [==============================] - 0s 1ms/step - loss: 60.0057
# Epoch 24/100
# 123/123 [==============================] - 0s 1ms/step - loss: 56.3296
# Epoch 25/100
# 123/123 [==============================] - 0s 1ms/step - loss: 53.5023
# Epoch 26/100
# 123/123 [==============================] - 0s 1ms/step - loss: 50.0880
# Epoch 27/100
# 123/123 [==============================] - 0s 1ms/step - loss: 47.4394
# Epoch 28/100
# 123/123 [==============================] - 0s 1ms/step - loss: 45.5517
# Epoch 29/100
# 123/123 [==============================] - 0s 1ms/step - loss: 43.3116
# Epoch 30/100
# 123/123 [==============================] - 0s 1ms/step - loss: 41.8071
# Epoch 31/100
# 123/123 [==============================] - 0s 1ms/step - loss: 39.4611
# Epoch 32/100
# 123/123 [==============================] - 0s 1ms/step - loss: 38.0421
# Epoch 33/100
# 123/123 [==============================] - 0s 1ms/step - loss: 37.1736
# Epoch 34/100
# 123/123 [==============================] - 0s 1ms/step - loss: 35.3108
# Epoch 35/100
# 123/123 [==============================] - 0s 1ms/step - loss: 33.8678
# Epoch 36/100
# 123/123 [==============================] - 0s 1ms/step - loss: 32.2862
# Epoch 37/100
# 123/123 [==============================] - 0s 1ms/step - loss: 31.1279
# Epoch 38/100
# 123/123 [==============================] - 0s 1ms/step - loss: 30.5282
# Epoch 39/100
# 123/123 [==============================] - 0s 1ms/step - loss: 30.4412
# Epoch 40/100
# 123/123 [==============================] - 0s 1ms/step - loss: 28.9116
# Epoch 41/100
# 123/123 [==============================] - 0s 1ms/step - loss: 27.7532
# Epoch 42/100
# 123/123 [==============================] - 0s 1ms/step - loss: 26.7052
# Epoch 43/100
# 123/123 [==============================] - 0s 1ms/step - loss: 25.9053
# Epoch 44/100
# 123/123 [==============================] - 0s 1ms/step - loss: 25.1556
# Epoch 45/100
# 123/123 [==============================] - 0s 1ms/step - loss: 25.0522
# Epoch 46/100
# 123/123 [==============================] - 0s 1ms/step - loss: 25.0375
# Epoch 47/100
# 123/123 [==============================] - 0s 1ms/step - loss: 24.2378
# Epoch 48/100
# 123/123 [==============================] - 0s 1ms/step - loss: 23.3505
# Epoch 49/100
# 123/123 [==============================] - 0s 1ms/step - loss: 22.5349
# Epoch 50/100
# 123/123 [==============================] - 0s 1ms/step - loss: 22.0094
# Epoch 51/100
# 123/123 [==============================] - 0s 1ms/step - loss: 21.6416
# Epoch 52/100
# 123/123 [==============================] - 0s 1ms/step - loss: 21.1863
# Epoch 53/100
# 123/123 [==============================] - 0s 1ms/step - loss: 20.5375
# Epoch 54/100
# 123/123 [==============================] - 0s 1ms/step - loss: 20.4025
# Epoch 55/100
# 123/123 [==============================] - 0s 1ms/step - loss: 19.8372
# Epoch 56/100
# 123/123 [==============================] - 0s 1ms/step - loss: 19.8445
# Epoch 57/100
# 123/123 [==============================] - 0s 1ms/step - loss: 19.3608
# Epoch 58/100
# 123/123 [==============================] - 0s 1ms/step - loss: 19.0355
# Epoch 59/100
# 123/123 [==============================] - 0s 1ms/step - loss: 18.6661
# Epoch 60/100
# 123/123 [==============================] - 0s 1ms/step - loss: 18.7754
# Epoch 61/100
# 123/123 [==============================] - 0s 1ms/step - loss: 18.4462
# Epoch 62/100
# 123/123 [==============================] - 0s 1ms/step - loss: 17.6972
# Epoch 63/100
# 123/123 [==============================] - 0s 1ms/step - loss: 17.8720
# Epoch 64/100
# 123/123 [==============================] - 0s 1ms/step - loss: 17.2003
# Epoch 65/100
# 123/123 [==============================] - 0s 1ms/step - loss: 17.2580
# Epoch 66/100
# 123/123 [==============================] - 0s 1ms/step - loss: 16.6437
# Epoch 67/100
# 123/123 [==============================] - 0s 1ms/step - loss: 16.9675
# Epoch 68/100
# 123/123 [==============================] - 0s 1ms/step - loss: 16.5724
# Epoch 69/100
# 123/123 [==============================] - 0s 1ms/step - loss: 16.2791
# Epoch 70/100
# 123/123 [==============================] - 0s 1ms/step - loss: 16.2345
# Epoch 71/100
# 123/123 [==============================] - 0s 1ms/step - loss: 15.9986
# Epoch 72/100
# 123/123 [==============================] - 0s 1ms/step - loss: 16.4039
# Epoch 73/100
# 123/123 [==============================] - 0s 1ms/step - loss: 15.9976
# Epoch 74/100
# 123/123 [==============================] - 0s 1ms/step - loss: 15.3503
# Epoch 75/100
# 123/123 [==============================] - 0s 1ms/step - loss: 15.1796
# Epoch 76/100
# 123/123 [==============================] - 0s 1ms/step - loss: 15.6308
# Epoch 77/100
# 123/123 [==============================] - 0s 1ms/step - loss: 14.9886
# Epoch 78/100
# 123/123 [==============================] - 0s 1ms/step - loss: 14.4759
# Epoch 79/100
# 123/123 [==============================] - 0s 1ms/step - loss: 14.8844
# Epoch 80/100
# 123/123 [==============================] - 0s 1ms/step - loss: 14.4826
# Epoch 81/100
# 123/123 [==============================] - 0s 1ms/step - loss: 14.2767
# Epoch 82/100
# 123/123 [==============================] - 0s 1ms/step - loss: 14.6497
# Epoch 83/100
# 123/123 [==============================] - 0s 1ms/step - loss: 14.0578
# Epoch 84/100
# 123/123 [==============================] - 0s 1ms/step - loss: 14.1844
# Epoch 85/100
# 123/123 [==============================] - 0s 1ms/step - loss: 14.0037
# Epoch 86/100
# 123/123 [==============================] - 0s 1ms/step - loss: 13.9793
# Epoch 87/100
# 123/123 [==============================] - 0s 1ms/step - loss: 13.6180
# Epoch 88/100
# 123/123 [==============================] - 0s 1ms/step - loss: 13.5507
# Epoch 89/100
# 123/123 [==============================] - 0s 1ms/step - loss: 13.1864
# Epoch 90/100
# 123/123 [==============================] - 0s 1ms/step - loss: 13.3885
# Epoch 91/100
# 123/123 [==============================] - 0s 965us/step - loss: 13.3323
# Epoch 92/100
# 123/123 [==============================] - 0s 901us/step - loss: 12.8456
# Epoch 93/100
# 123/123 [==============================] - 0s 1ms/step - loss: 13.4107
# Epoch 94/100
# 123/123 [==============================] - 0s 898us/step - loss: 12.6449
# Epoch 95/100
# 123/123 [==============================] - 0s 1ms/step - loss: 12.7042
# Epoch 96/100
# 123/123 [==============================] - 0s 920us/step - loss: 12.6731
# Epoch 97/100
# 123/123 [==============================] - 0s 908us/step - loss: 12.6446
# Epoch 98/100
# 123/123 [==============================] - 0s 914us/step - loss: 12.4805
# Epoch 99/100
# 123/123 [==============================] - 0s 883us/step - loss: 12.3842
# Epoch 100/100
# 123/123 [==============================] - 0s 914us/step - loss: 12.4117

# %%
y_pred=model.predict(X_sl_test)
# Out:
# 31/31 [==============================] - 0s 720us/step

# %%
y_pred
# Out:
# array([[251.34732],
#        [303.8793 ],
#        [258.43213],
#        [175.41476],
#        [296.64938],
#        [193.59413],
#        [254.8474 ],
#        [320.31924],
#        [301.06772],
#        [261.72092],
#        [207.05989],
#        [219.47292],
#        [271.54764],
#        [289.63718],
#        [262.78363],
#        [263.7809 ],
#        [272.49667],
#        [189.89723],
#        [309.47266],
#        [271.1558 ],
#        [188.88666],
#        [311.96503],
#        [232.84364],
#        [307.82678],
#        [194.7264 ],
#        [236.27296],
#        [176.05247],
#        [218.8591 ],
#        [310.54684],
#        [249.44305],
#        [279.38678],
#        [287.79135],
#        [205.57616],
#        [273.49478],
#        [185.48737],
#        [295.10297],
#        [173.73543],
#        [213.06139],
#        [217.41422],
#        [310.53036],
#        [184.73283],
#        [201.3936 ],
#        [249.94067],
#        [262.8548 ],
#        [255.5841 ],
#        [302.71524],
#        [262.74887],
#        [254.97891],
#        [326.46213],
#        [249.65526],
#        [311.30484],
#        [311.34616],
#        [218.82619],
#        [265.55438],
#        [222.47386],
#        [224.91786],
#        [233.56987],
#        [287.9704 ],
#        [292.07938],
#        [210.45985],
#        [305.34433],
#        [258.26016],
#        [226.03215],
#        [273.1256 ],
#        [181.28914],
#        [190.86134],
#        [170.64748],
#        [252.56459],
#        [220.57825],
#        [297.98703],
#        [218.5168 ],
#        [279.1432 ],
#        [189.1121 ],
#        [194.44073],
#        [273.94434],
#        [273.49478],
#        [172.88747],
#        [207.50035],
#        [283.1356 ],
#        [195.59244],
#        [280.03854],
#        [199.66052],
#        [320.98563],
#        [264.59274],
#        [188.72911],
#        [174.63744],
#        [184.33919],
#        [206.95139],
#        [238.74313],
#        [306.9431 ],
#        [307.49945],
#        [176.158  ],
#        [276.8859 ],
#        [294.6118 ],
#        [227.84349],
#        [226.85579],
#        [253.65123],
#        [187.94261],
#        [246.5014 ],
#        [256.8977 ],
#        [257.57278],
#        [204.69377],
#        [306.18008],
#        [286.60886],
#        [227.92351],
#        [225.29866],
#        [227.31786],
#        [199.88591],
#        [248.58495],
#        [284.0995 ],
#        [250.9074 ],
#        [224.95372],
#        [187.9109 ],
#        [271.1312 ],
#        [195.15614],
#        [198.49419],
#        [190.234  ],
#        [247.79173],
#        [210.75227],
#        [228.25891],
#        [273.85507],
#        [318.08   ],
#        [188.7835 ],
#        [263.1314 ],
#        [220.10188],
#        [237.55032],
#        [258.08218],
#        [190.23401],
#        [200.14972],
#        [201.15947],
#        [201.3406 ],
#        [253.93126],
#        [281.29343],
#        [279.90988],
#        [251.83224],
#        [274.54404],
#        [187.4667 ],
#        [255.30283],
#        [191.7205 ],
#        [258.56784],
#        [297.40567],
#        [264.78726],
#        [233.35048],
#        [252.77936],
#        [206.65544],
#        [297.05612],
#        [200.21706],
#        [223.69339],
#        [192.87172],
#        [254.63522],
#        [302.61517],
#        [194.9485 ],
#        [237.1962 ],
#        [284.43674],
#        [211.70992],
#        [241.7328 ],
#        [226.55484],
#        [257.0714 ],
#        [226.25125],
#        [169.63185],
#        [171.09923],
#        [209.98296],
#        [202.70146],
#        [194.34698],
#        [309.70767],
#        [237.89679],
#        [208.37148],
#        [232.84364],
#        [209.47765],
#        [221.85966],
#        [197.14287],
#        [241.43301],
#        [320.1937 ],
#        [333.33817],
#        [241.98396],
#        [197.15907],
#        [242.21947],
#        [274.10297],
#        [241.34627],
#        [266.00693],
#        [195.66338],
#        [260.85123],
#        [220.17953],
#        [203.61678],
#        [328.6314 ],
#        [220.65599],
#        [218.3943 ],
#        [188.7835 ],
#        [180.45573],
#        [243.79175],
#        [258.9789 ],
#        [285.9345 ],
#        [209.04662],
#        [311.72583],
#        [193.88579],
#        [186.44382],
#        [199.58101],
#        [252.54599],
#        [221.39285],
#        [208.16208],
#        [273.45285],
#        [251.40144],
#        [276.64813],
#        [182.20757],
#        [299.74582],
#        [275.82614],
#        [276.70627],
#        [206.80743],
#        [189.45578],
#        [300.83438],
#        [259.17426],
#        [244.89055],
#        [243.0181 ],
#        [242.15059],
#        [196.5419 ],
#        [199.5092 ],
#        [207.1965 ],
#        [204.7491 ],
#        [219.52376],
#        [212.07454],
#        [219.67607],
#        [223.73973],
#        [282.50296],
#        [305.09274],
#        [213.45671],
#        [211.26974],
#        [251.05836],
#        [264.45197],
#        [263.8287 ],
#        [285.25687],
#        [296.8869 ],
#        [258.0822 ],
#        [256.19766],
#        [204.7431 ],
#        [200.21362],
#        [206.80743],
#        [203.91586],
#        [217.78566],
#        [259.38928],
#        [292.1058 ],
#        [191.03593],
#        [202.28972],
#        [174.7494 ],
#        [213.13614],
#        [275.1391 ],
#        [255.37737],
#        [226.16972],
#        [233.00435],
#        [187.9323 ],
#        [279.23746],
#        [228.9329 ],
#        [296.7455 ],
#        [306.4997 ],
#        [241.641  ],
#        [171.77962],
#        [231.75995],
#        [291.38467],
#        [221.1256 ],
#        [299.74582],
#        [191.76012],
#        [240.2597 ],
#        [299.87384],
#        [211.03032],
#        [183.2874 ],
#        [204.69377],
#        [248.50633],
#        [193.34985],
#        [245.4532 ],
#        [299.5383 ],
#        [265.70358],
#        [190.60127],
#        [190.66829],
#        [245.70805],
#        [318.98337],
#        [289.5635 ],
#        [212.58534],
#        [176.40987],
#        [230.77324],
#        [207.78621],
#        [194.63507],
#        [289.32748],
#        [284.91434],
#        [228.22102],
#        [230.12228],
#        [249.65526],
#        [302.71524],
#        [214.06242],
#        [291.4661 ],
#        [271.30048],
#        [171.79045],
#        [271.04376],
#        [297.08987],
#        [299.0272 ],
#        [187.86223],
#        [179.52983],
#        [236.1541 ],
#        [219.3189 ],
#        [254.01865],
#        [212.08656],
#        [275.61795],
#        [231.41841],
#        [220.17146],
#        [191.65242],
#        [224.91786],
#        [207.76215],
#        [219.25533],
#        [317.45447],
#        [272.0509 ],
#        [221.49005],
#        [246.78755],
#        [267.37363],
#        [221.4549 ],
#        [253.21936],
#        [298.67636],
#        [241.25859],
#        [214.66142],
#        [248.23106],
#        [217.53362],
#        [205.74022],
#        [245.67265],
#        [227.51357],
#        [295.06308],
#        [302.04868],
#        [252.85335],
#        [239.15529],
#        [218.82619],
#        [202.78291],
#        [213.2264 ],
#        [238.91927],
#        [283.32004],
#        [208.08429],
#        [255.17218],
#        [296.07614],
#        [264.92123],
#        [218.99345],
#        [219.01196],
#        [261.1622 ],
#        [189.41136],
#        [283.0474 ],
#        [228.9425 ],
#        [287.23053],
#        [258.70813],
#        [219.84615],
#        [247.14398],
#        [251.35815],
#        [187.3486 ],
#        [188.88858],
#        [260.49625],
#        [229.90297],
#        [272.2875 ],
#        [200.34335],
#        [236.27298],
#        [184.58394],
#        [267.09222],
#        [296.8387 ],
#        [236.76454],
#        [222.49292],
#        [196.51079],
#        [310.50757],
#        [267.21625],
#        [230.16362],
#        [261.01453],
#        [266.98532],
#        [301.68887],
#        [190.56563],
#        [294.39474],
#        [236.84714],
#        [298.67636],
#        [324.0634 ],
#        [237.89412],
#        [227.60696],
#        [179.26411],
#        [181.17567],
#        [246.70195],
#        [210.3279 ],
#        [198.64159],
#        [247.55365],
#        [217.94627],
#        [294.81686],
#        [263.2353 ],
#        [245.4532 ],
#        [202.68193],
#        [231.75995],
#        [206.14668],
#        [250.07878],
#        [230.97372],
#        [206.34718],
#        [312.0273 ],
#        [263.44724],
#        [256.55246],
#        [217.31416],
#        [315.6177 ],
#        [217.26454],
#        [173.47256],
#        [200.08638],
#        [322.16165],
#        [226.67659],
#        [214.48325],
#        [286.1883 ],
#        [196.43495],
#        [210.32408],
#        [191.77614],
#        [193.29674],
#        [230.84546],
#        [212.1136 ],
#        [226.13576],
#        [200.40097],
#        [263.31375],
#        [184.93968],
#        [189.42126],
#        [210.84377],
#        [225.2965 ],
#        [235.93971],
#        [249.26009],
#        [317.4545 ],
#        [230.16362],
#        [254.08997],
#        [192.83281],
#        [240.00401],
#        [203.68214],
#        [263.86737],
#        [208.97972],
#        [202.41718],
#        [222.20161],
#        [209.97685],
#        [307.62634],
#        [284.19818],
#        [327.96042],
#        [237.55032],
#        [220.71237],
#        [243.34492],
#        [188.44652],
#        [287.23053],
#        [206.7986 ],
#        [214.02959],
#        [190.08293],
#        [288.4694 ],
#        [229.55333],
#        [204.82721],
#        [220.17953],
#        [248.70316],
#        [274.55142],
#        [240.03767],
#        [176.79713],
#        [181.33003],
#        [213.14877],
#        [271.81433],
#        [220.32825],
#        [193.5795 ],
#        [311.64285],
#        [318.58893],
#        [192.51259],
#        [317.28192],
#        [243.69078],
#        [218.41011],
#        [204.58777],
#        [266.86768],
#        [192.99301],
#        [216.669  ],
#        [289.36813],
#        [189.27269],
#        [301.52823],
#        [224.46281],
#        [222.49292],
#        [257.23987],
#        [199.88591],
#        [303.4827 ],
#        [230.79039],
#        [253.39386],
#        [277.9596 ],
#        [248.75197],
#        [254.96992],
#        [321.57385],
#        [320.31924],
#        [258.70813],
#        [206.01312],
#        [254.05257],
#        [256.82532],
#        [220.945  ],
#        [187.45088],
#        [248.85056],
#        [296.64938],
#        [274.52292],
#        [281.6182 ],
#        [245.34122],
#        [224.05641],
#        [313.80496],
#        [196.30635],
#        [193.03474],
#        [262.0532 ],
#        [255.48885],
#        [182.70009],
#        [207.46361],
#        [258.26016],
#        [179.06435],
#        [261.34164],
#        [274.38394],
#        [265.04733],
#        [221.14142],
#        [264.9245 ],
#        [306.77832],
#        [202.27295],
#        [241.14233],
#        [250.22737],
#        [262.58878],
#        [198.6234 ],
#        [246.86276],
#        [265.3263 ],
#        [187.98131],
#        [261.80795],
#        [244.96815],
#        [285.4346 ],
#        [188.30098],
#        [255.59067],
#        [219.50168],
#        [319.58282],
#        [273.94434],
#        [244.17479],
#        [233.18552],
#        [270.3918 ],
#        [227.14017],
#        [199.88591],
#        [195.87852],
#        [255.96729],
#        [217.14241],
#        [176.05247],
#        [233.00435],
#        [214.44931],
#        [271.5299 ],
#        [204.6368 ],
#        [268.55612],
#        [211.033  ],
#        [267.99792],
#        [252.20282],
#        [213.34119],
#        [214.43367],
#        [177.10918],
#        [229.19917],
#        [253.11307],
#        [210.53654],
#        [300.83438],
#        [230.97372],
#        [205.74022],
#        [273.7135 ],
#        [229.99127],
#        [220.18709],
#        [218.85524],
#        [252.6808 ],
#        [272.40744],
#        [199.21379],
#        [249.36156],
#        [246.23589],
#        [262.92514],
#        [198.3488 ],
#        [227.14058],
#        [195.87852],
#        [191.70068],
#        [212.76775],
#        [194.58226],
#        [237.62166],
#        [215.36063],
#        [182.17567],
#        [199.1584 ],
#        [238.721  ],
#        [312.0847 ],
#        [221.14142],
#        [195.82805],
#        [228.87117],
#        [223.11978],
#        [237.03197],
#        [253.3637 ],
#        [213.99745],
#        [310.50757],
#        [280.44247],
#        [233.49089],
#        [179.74893],
#        [170.74596],
#        [199.29079],
#        [238.721  ],
#        [257.67258],
#        [266.9313 ],
#        [200.29329],
#        [200.82272],
#        [261.1085 ],
#        [269.13315],
#        [177.26523],
#        [203.51372],
#        [180.20442],
#        [173.07976],
#        [221.80138],
#        [291.26273],
#        [197.27016],
#        [200.28705],
#        [204.69377],
#        [214.54599],
#        [242.28114],
#        [246.40808],
#        [251.01926],
#        [179.61551],
#        [233.00717],
#        [251.56961],
#        [284.59354],
#        [325.52933],
#        [300.00015],
#        [315.17313],
#        [201.06435],
#        [268.79532],
#        [270.35095],
#        [274.01114],
#        [193.26357],
#        [186.15074],
#        [297.05905],
#        [281.97162],
#        [206.29004],
#        [266.59604],
#        [187.8801 ],
#        [207.87538],
#        [283.32004],
#        [169.74864],
#        [302.71524],
#        [306.9431 ],
#        [246.30281],
#        [203.63448],
#        [204.3228 ],
#        [249.9187 ],
#        [187.49345],
#        [245.83745],
#        [256.73386],
#        [241.55458],
#        [234.2324 ],
#        [202.22989],
#        [298.33276],
#        [220.32324],
#        [228.68184],
#        [201.68842],
#        [296.27487],
#        [203.26936],
#        [222.20161],
#        [263.0746 ],
#        [254.83554],
#        [196.26164],
#        [245.4532 ],
#        [222.5533 ],
#        [225.0658 ],
#        [271.1213 ],
#        [246.4238 ],
#        [250.1435 ],
#        [309.33136],
#        [309.47266],
#        [203.36052],
#        [257.67258],
#        [288.4694 ],
#        [209.58913],
#        [253.94205],
#        [176.42546],
#        [276.00934],
#        [204.88356],
#        [225.66173],
#        [246.86276],
#        [208.21758],
#        [295.9023 ],
#        [262.59097],
#        [209.69307],
#        [258.38284],
#        [256.21133],
#        [215.56575],
#        [206.92259],
#        [242.17447],
#        [181.17567],
#        [234.37207],
#        [283.95132],
#        [276.8275 ],
#        [321.21863],
#        [228.08893],
#        [195.15614],
#        [248.57155],
#        [182.02144],
#        [206.00781],
#        [207.47353],
#        [273.4092 ],
#        [237.28465],
#        [296.27487],
#        [210.9951 ],
#        [211.46332],
#        [262.74887],
#        [220.93529],
#        [221.20798],
#        [214.90791],
#        [209.47765],
#        [223.72441],
#        [196.37563],
#        [296.97495],
#        [264.62527],
#        [272.5264 ],
#        [271.697  ],
#        [294.83252],
#        [170.24425],
#        [272.04962],
#        [221.1256 ],
#        [206.68292],
#        [226.04292],
#        [233.24469],
#        [298.3328 ],
#        [264.88672],
#        [203.56139],
#        [282.02573],
#        [235.24739],
#        [224.49348],
#        [274.96924],
#        [248.83327],
#        [271.0026 ],
#        [188.98946],
#        [238.78346],
#        [228.52946],
#        [304.82825],
#        [307.75815],
#        [231.99895],
#        [209.9092 ],
#        [224.49348],
#        [211.73802],
#        [202.4076 ],
#        [228.43364],
#        [297.26865],
#        [171.81352],
#        [293.52982],
#        [202.99939],
#        [290.3959 ],
#        [306.61752],
#        [187.94261],
#        [303.21085],
#        [324.81595],
#        [184.03835],
#        [306.9321 ],
#        [240.21169],
#        [178.12082],
#        [217.95158],
#        [235.36708],
#        [273.37045],
#        [311.49896],
#        [228.24188],
#        [288.4694 ],
#        [249.36156],
#        [232.1229 ],
#        [181.90474],
#        [185.06555],
#        [322.2009 ],
#        [209.85887],
#        [194.79744],
#        [289.04868],
#        [195.94138],
#        [258.70813],
#        [177.77098],
#        [284.81863],
#        [319.22183],
#        [240.00401],
#        [256.40817],
#        [212.13805],
#        [209.2155 ],
#        [219.24374],
#        [203.61678],
#        [225.18416],
#        [269.74783],
#        [243.80693],
#        [275.67053],
#        [189.74861],
#        [311.34616],
#        [285.45627],
#        [257.22946],
#        [248.25902],
#        [227.8881 ],
#        [242.63593],
#        [214.88054],
#        [220.11598],
#        [233.30641],
#        [221.97786],
#        [195.15614],
#        [248.6872 ],
#        [266.57974],
#        [251.55605],
#        [235.99469],
#        [246.31616],
#        [286.76486],
#        [245.2719 ],
#        [284.1061 ],
#        [250.51247],
#        [234.61592],
#        [279.23743],
#        [219.3068 ],
#        [293.57053],
#        [202.723  ],
#        [189.94882],
#        [185.59239],
#        [280.87912],
#        [277.94888],
#        [319.92816],
#        [221.4549 ],
#        [229.37872],
#        [238.68385],
#        [285.57266],
#        [181.17569],
#        [248.11827],
#        [253.39386],
#        [224.20633],
#        [189.37439],
#        [208.27182],
#        [233.28311],
#        [304.82266],
#        [189.97876],
#        [174.99864],
#        [259.82663],
#        [262.8232 ],
#        [230.23068],
#        [229.15129],
#        [186.6345 ],
#        [226.95891],
#        [195.75975],
#        [262.2378 ],
#        [258.70813],
#        [253.48935],
#        [211.73802],
#        [226.86205],
#        [220.02849],
#        [185.04878],
#        [195.82622],
#        [242.95084],
#        [178.97249],
#        [244.37325],
#        [255.52063],
#        [232.6516 ],
#        [185.48737],
#        [211.6166 ],
#        [206.46997],
#        [317.21   ],
#        [315.6177 ],
#        [298.67636],
#        [179.5107 ],
#        [207.55217],
#        [231.47142],
#        [249.86844],
#        [240.2597 ],
#        [267.23315],
#        [203.00972],
#        [216.66061],
#        [312.98593],
#        [198.50696],
#        [318.58893],
#        [248.18553],
#        [262.61826],
#        [256.6871 ],
#        [229.30728],
#        [292.60556],
#        [170.4597 ],
#        [172.92815],
#        [210.78966],
#        [251.12215],
#        [301.80246],
#        [311.8228 ],
#        [197.15865],
#        [206.76118],
#        [175.45497],
#        [317.73392],
#        [288.56253],
#        [219.01198],
#        [182.90483],
#        [239.5544 ],
#        [203.09242],
#        [328.84018],
#        [221.9634 ],
#        [221.1256 ],
#        [250.26323],
#        [227.67015],
#        [201.72462],
#        [228.22102],
#        [249.4586 ],
#        [196.5155 ],
#        [240.61757],
#        [293.52982],
#        [176.79713],
#        [218.85524],
#        [255.22925],
#        [273.49478],
#        [276.63666],
#        [240.61757],
#        [194.34698],
#        [236.62694],
#        [224.92958],
#        [220.33043],
#        [232.56969],
#        [195.87852],
#        [226.19225],
#        [196.5155 ],
#        [316.56714],
#        [227.37328],
#        [246.07625],
#        [200.01726],
#        [314.41565],
#        [221.31319],
#        [274.30148],
#        [231.82463],
#        [177.52312],
#        [217.58318],
#        [290.71518],
#        [229.76718],
#        [242.76784],
#        [246.40808],
#        [248.87672],
#        [294.34714],
#        [253.29381],
#        [239.4984 ],
#        [249.0312 ],
#        [227.63028],
#        [213.47804],
#        [188.29141],
#        [260.32596],
#        [270.6711 ],
#        [177.26523],
#        [215.41588],
#        [198.05835],
#        [211.96837],
#        [211.34108],
#        [186.43852],
#        [203.25339],
#        [232.84364],
#        [277.6451 ],
#        [252.51276],
#        [234.73058],
#        [175.68532],
#        [277.04886],
#        [218.4001 ],
#        [214.48325],
#        [242.5074 ],
#        [305.69803],
#        [192.54291],
#        [205.68298],
#        [275.96597],
#        [307.82678],
#        [271.03006],
#        [199.27338],
#        [190.234  ],
#        [259.55646],
#        [207.83234],
#        [271.38162],
#        [174.49745],
#        [306.20724],
#        [174.04369],
#        [180.76793],
#        [192.84564],
#        [222.80637],
#        [212.06557],
#        [315.10794],
#        [214.06242],
#        [294.9479 ],
#        [225.01262],
#        [184.13228],
#        [248.13797],
#        [296.42352],
#        [228.01619],
#        [311.49896],
#        [227.2505 ],
#        [178.73534],
#        [274.76865],
#        [322.16165],
#        [262.07016],
#        [212.13805],
#        [259.60867],
#        [239.39928],
#        [227.07175],
#        [205.97667],
#        [282.30957],
#        [321.57385],
#        [184.09026],
#        [194.97041],
#        [254.04384],
#        [250.96036],
#        [283.45865],
#        [245.24649],
#        [219.42332],
#        [226.86205],
#        [251.5479 ],
#        [225.00156],
#        [266.57974],
#        [229.29207],
#        [240.13716],
#        [241.09607]], dtype=float32)

# %%
R_2=metrics.r2_score(y_test,y_pred)
R_2
# Out:
# 0.9929241635158478

# %%
# After performing all the models we found out that Random forest with hyper tuning model provides best R2 score

# %% [markdown]
# # Model Validation

# %%
from sklearn.model_selection import KFold
kf = KFold(n_splits = 10)

def Get_score(model, X_train_k, X_test_k, y_train_k, y_test_k):
    model.fit(X_train_k, y_train_k)
    return model.score(X_test_k, y_test_k)  

X_train, X_test, y_train, y_test = train_test_split(x, y, random_state = 10, test_size = 0.3)

# %%
scores = []
 
for train_index, test_index in kf.split(X_train):
    X_train_k, X_test_k, y_train_k, y_test_k = X_train.iloc[train_index], X_train.iloc[test_index], \
                                               y_train.iloc[train_index], y_train.iloc[test_index]
 
    scores.append(Get_score(regressor, X_train_k, X_test_k, y_train_k, y_test_k)) 
    

print('All scores: ', scores)
print("\nMinimum score obtained: ", round(min(scores), 4))
print("Maximum score obtained: ", round(max(scores), 4))
print("Average score obtained: ", round(np.mean(scores), 4))
# Out:
# All scores:  [0.9934650889403691, 0.9964688257844726, 0.99608463672194, 0.9969271092852213, 0.9961231564393568, 0.9742952156539392, 0.985695338888196, 0.9942992193054669, 0.9964143914066846, 0.9960220313101781]
#
# Minimum score obtained:  0.9743
# Maximum score obtained:  0.9969
# Average score obtained:  0.9926

# %%
scores = cross_val_score(estimator = regressor, 
                         X = X_train, 
                         y = y_train, 
                         cv = 10, 
                         scoring = 'r2')

print('All scores: ', scores)
print("\nMinimum score obtained: ", round(min(scores), 4))
print("Maximum score obtained: ", round(max(scores), 4))
print("Average score obtained: ", round(np.mean(scores), 4))
# Out:
# All scores:  [0.99346509 0.99646883 0.99608464 0.99692711 0.99612316 0.97429522
#  0.98569534 0.99429922 0.99641439 0.99602203]
#
# Minimum score obtained:  0.9743
# Maximum score obtained:  0.9969
# Average score obtained:  0.9926

# %% [markdown]
# # The R2 value is similar to the one obtained in the RF model. There are no significant changes.

# %%
import pickle

# %%
regressor
# Out:
# RandomForestRegressor(random_state=42)

# %%
filename = 'random_regressor.sav'
pickle.dump(regressor, open(filename, 'wb'))
